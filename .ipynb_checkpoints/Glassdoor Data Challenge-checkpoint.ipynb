# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
pd.set_option("display.max_columns", 999)
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Data Import

# %%
datarun = pd.read_csv("input/data_challenge_rundata.csv", index_col=0)
datatrain = pd.read_csv("input/data_challenge_traindata.csv", index_col=0)

# %% [markdown]
# Run and training data dimensions

# %%
print(datarun.shape, datatrain.shape)
# Out:
# (100000, 20) (16901, 21)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Exploratory data analysis based on univariate analysis and visualization using [Seaborn](https://seaborn.pydata.org/) library.

# %% [markdown]
# ## A. Categorical Predictor

# %%
def plot_win_pct(bycat, data=datatrain, hori=True):
    """
    plot winning percentage by category variable bycat
    
    """
    df0 = datatrain[['isWon', bycat]].groupby(bycat).agg('mean')
    df0.columns = ['win_pct']
    df0 = df0.sort_values('win_pct', ascending=False)
    df0[bycat] = df0.index
    df0.index = range(df0.shape[0])
    
    if hori == True:
        sns.barplot(y=bycat, x="win_pct", data=df0, color="cornflowerblue")
        plt.axvline(x=datatrain['isWon'].mean(), color='red')
    else:
        sns.barplot(x=bycat, y="win_pct", data=df0, color="cornflowerblue")
        plt.axhline(y=datatrain['isWon'].mean(), color='red')

# %% [markdown]
# ### 1. Industry
#
# The red vertical line represents the average for all observations (0.109). With this, we can easily see which is above and below the average for all. Agriculture & Forestry has the highest winning percentage. Media, Government and Mining & Metals have the lowest winning percentages.
#
# Clearly, industry should play an important role in winning percentage.

# %%
# average for all
datatrain['isWon'].mean()
# Out:
# 0.10916513815750548

# %%
plt.figure(figsize=(11,8))
plot_win_pct('Industry')

# %% [markdown]
# ### 2. ATS__c
#
# Similarly with Industry, applicant tracking system (ATS) also plays an imporant role in affacting the winning likelihood. "EMPLOYER SOURCE" and "WorkforceNow are very high and only "OpenHire", "app.theresumator.com", "WorkableHR.com", and "UNKOWN" are below the average.

# %%
plt.figure(figsize=(11,8))
plot_win_pct('ATS__c')

# %% [markdown]
# ### 3. Subsidiary
#
# If the employer is a subsidiary (subsidiary=1), the winning likelihood is higher.

# %%
plt.figure(figsize=(10,7))
plot_win_pct('subsidiary', hori=False)

# %% [markdown]
# ### 4. has_interviews
#
# If the employter has interviews on their profile, winning likelihood is doubled.

# %%
plt.figure(figsize=(10,7))
plot_win_pct('has_interviews', hori=False)

# %% [markdown]
# ## B. Continuous Predictor
#
# For continuous predictor, we make a boxplot using certain predictor versus "isWon". Intuitively, it should tell us whether certain predictor performs good or bad. However, some predictor such as "numJobs", "clicks" and "awards" etc. has a very large scale and also has many outliers. It makes the boxplot look terrible.

# %% [markdown]
# ### 1. employeesTotalNum

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='employeesTotalNum', data=datatrain)

# %% [markdown]
# ### 2. monthOfSignupPageViews

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='monthOfSignupPageViews', data=datatrain)

# %% [markdown]
# ### 3. clicks

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='clicks', data=datatrain)

# %% [markdown]
# ### 4. timeOnSite
#
# It seems that winning employers have a slightly higher timeOnSite.

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='timeOnSite', data=datatrain)

# %% [markdown]
# ### 5. starRating
#
# StarRatings are basically the same for the two winning groups.

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='starRating', data=datatrain)

# %% [markdown]
# ### 6. numJobs

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='numJobs', data=datatrain)

# %% [markdown]
# ### 7. award
#
# Winning group has a lower concentrated award counts.

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='awards', data=datatrain)

# %% [markdown]
# ### 8. contentCount

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='contentCount', data=datatrain)

# %% [markdown]
# ### 9. freshContent

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='freshContent', data=datatrain)

# %% [markdown]
# ### 10. followers

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='followers', data=datatrain)

# %% [markdown]
# ### 11. photos

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='photos', data=datatrain)

# %% [markdown]
# ### 12. intDifficulty
#
# It seems that interview difficulty does not have an effect.

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='intDifficulty', data=datatrain)

# %% [markdown]
# ### 13. intDuration
#
# It seems that interview difficulty does not have an effect.

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='intDuration', data=datatrain)

# %% [markdown]
# ### 14. basePayAmount

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='basePayAmount', data=datatrain)

# %% [markdown]
# ### 15. RespondedContacts

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='isWon', y='RespondedContacts', data=datatrain)

# %% [markdown]
# # Concerns About the Data

# %% [markdown]
# ### 1. Duplicates in the Train Data
#
# EmployerId should be unique. However, we observe that there are 2 observations in the train data having the same "employerId".

# %%
datatrain.shape
# Out:
# (16901, 21)

# %%
len(set(datatrain['employerId']))
# Out:
# 16900

# %%
datatrain['employerId'].value_counts()[datatrain['employerId'].value_counts() > 1]
# Out:
# 2bX4R    2
# Name: employerId, dtype: int64

# %%
datatrain[datatrain['employerId'] == '2bX4R']
# Out:
#            ATS__c                 Industry  numJobs  awards  contentCount  \
# 186   CustomCrawl  Advertising & Marketing      8.0     0.0           8.0
# 4514      UNKNOWN            Manufacturing      0.0     0.0          84.0
#
#       followers  freshContent  photos  starRating  clicks  \
# 186        14.0           0.0     0.0    4.666667     1.0
# 4514      424.0          12.0    22.0    2.736842   379.0
#
#       monthOfSignupPageViews  timeOnSite  intDifficulty  intDuration  \
# 186                     61.0         650            2.0         10.0
# 4514                  2602.0         807            2.5         29.0
#
#       has_interviews  basePayAmount  subsidiary  employeesTotalNum  \
# 186                1        60000.0           0              125.0
# 4514               1       106811.0           0              169.0
#
#       RespondedContacts employerId  isWon
# 186                 1.0      2bX4R  False
# 4514                NaN      2bX4R  False

# %% [markdown]
# ### 2. Some employerId in the Run Data can be found in the Train Data

# %%
len(set(datatrain['employerId']) & set(datarun['employerId']))
# Out:
# 11664

# %%
len(set(datarun['employerId']))
# Out:
# 99991

# %% [markdown]
# An example could be found below. When we build up the model, we could actually cheat on employerId. We can search the employerId in the Train Data and use the result directly for the run data.

# %%
datatrain[datatrain['employerId'] == '40NNQ']
# Out:
#         ATS__c                 Industry  numJobs  awards  contentCount  \
# 14563  UNKNOWN  Advertising & Marketing      0.0     NaN           NaN
#
#        followers  freshContent  photos  starRating  clicks  \
# 14563        NaN           NaN     NaN         NaN     NaN
#
#        monthOfSignupPageViews  timeOnSite  intDifficulty  intDuration  \
# 14563                     NaN         681            2.6         19.0
#
#        has_interviews  basePayAmount  subsidiary  employeesTotalNum  \
# 14563               1        43832.0           0              210.0
#
#        RespondedContacts employerId  isWon
# 14563                1.0      40NNQ  False

# %%
datarun[datarun['employerId'] == '40NNQ']
# Out:
#        ATS__c                 Industry  numJobs  awards  contentCount  \
# 9368  UNKNOWN  Advertising & Marketing      NaN     0.0          96.0
#
#       followers  freshContent  photos  starRating  clicks  \
# 9368      230.0           2.0     0.0    3.820513    18.0
#
#       monthOfSignupPageViews  timeOnSite  intDifficulty  intDuration  \
# 9368                   453.0         674            2.8         19.0
#
#       has_interviews  basePayAmount  subsidiary  employeesTotalNum  \
# 9368               1        43832.0           0              210.0
#
#       RespondedContacts employerId
# 9368                1.0      40NNQ

# %% [markdown]
# ### 3. Missing Values
#
# There are so many missing values in the Train Data. Some methods such as tree methods will be able to deal with missing values directly. However, some algorithm such as logistic regression model cannot deal with missing values unless imputing the missing values beforehand. The missing values can be a big problem

# %%
pd.DataFrame({'Missing Count':datatrain.apply(lambda x: sum(x.isna()), axis=0).sort_values(),
              'Percentage':datatrain.apply(lambda x: sum(x.isna()), axis=0).sort_values()/datatrain.shape[0]})
# Out:
#                         Missing Count  Percentage
# isWon                               0    0.000000
# subsidiary                          0    0.000000
# numJobs                             0    0.000000
# basePayAmount                       0    0.000000
# has_interviews                      0    0.000000
# timeOnSite                          0    0.000000
# employerId                          0    0.000000
# ATS__c                              4    0.000237
# employeesTotalNum                 172    0.010177
# Industry                          602    0.035619
# RespondedContacts                2674    0.158215
# intDifficulty                    2839    0.167978
# intDuration                      3149    0.186320
# freshContent                     3292    0.194781
# followers                        3292    0.194781
# contentCount                     3292    0.194781
# awards                           3292    0.194781
# photos                           3292    0.194781
# starRating                       3956    0.234069
# monthOfSignupPageViews           4708    0.278563
# clicks                           6037    0.357198

# %% [markdown]
# For the missing values in ATS__c and Industry, we will just create a new level for them or combine them with the existing "UNKNOWN" level.

# %%
datatrain['ATS__c'][datatrain['ATS__c'].isna()] = "UNKNOWN"
datarun['ATS__c'][datarun['ATS__c'].isna()] = "UNKNOWN"
datatrain['Industry'][datatrain['Industry'].isna()] = "UNKNOWN"
datarun['Industry'][datarun['Industry'].isna()] = "UNKNOWN"
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
pd.DataFrame({'Missing Count':datatrain.apply(lambda x: sum(x.isna()), axis=0).sort_values(),
              'Percentage':datatrain.apply(lambda x: sum(x.isna()), axis=0).sort_values()/datatrain.shape[0]})
# Out:
#                         Missing Count  Percentage
# ATS__c                              0    0.000000
# subsidiary                          0    0.000000
# basePayAmount                       0    0.000000
# has_interviews                      0    0.000000
# timeOnSite                          0    0.000000
# employerId                          0    0.000000
# isWon                               0    0.000000
# numJobs                             0    0.000000
# Industry                            0    0.000000
# employeesTotalNum                 172    0.010177
# RespondedContacts                2674    0.158215
# intDifficulty                    2839    0.167978
# intDuration                      3149    0.186320
# photos                           3292    0.194781
# followers                        3292    0.194781
# contentCount                     3292    0.194781
# awards                           3292    0.194781
# freshContent                     3292    0.194781
# starRating                       3956    0.234069
# monthOfSignupPageViews           4708    0.278563
# clicks                           6037    0.357198

# %% [markdown]
# ### 4. Unbalanced Data

# %% [markdown]
# Data is very unbalanced. Only 10.9% of the observations is the winning cases. The remaining 89.1% are all failure cases.

# %%
datatrain['isWon'].value_counts() / datatrain.shape[0]
# Out:
# False    0.890835
# True     0.109165
# Name: isWon, dtype: float64

# %% [markdown]
# ### 5. Outliers
#
# As we showed before, for some continuous predictor such as click etc, there can be a lot of outliers. The outliers can harm the analysis.

# %% [markdown]
# ### 6. Predictor Normalization
#
# Some predictor has a very large scale. Maybe we should normalize these predictors.

# %% [markdown]
# # Model Building

# %% [markdown]
# ## 1. Label Encoding
#
# Convert categorical predictor to integers.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
datatrain.columns.to_series().groupby(datatrain.dtypes).groups
# Out:
# {dtype('bool'): Index(['isWon'], dtype='object'),
#  dtype('int64'): Index(['timeOnSite', 'has_interviews', 'subsidiary'], dtype='object'),
#  dtype('float64'): Index(['numJobs', 'awards', 'contentCount', 'followers', 'freshContent',
#         'photos', 'starRating', 'clicks', 'monthOfSignupPageViews',
#         'intDifficulty', 'intDuration', 'basePayAmount', 'employeesTotalNum',
#         'RespondedContacts'],
#        dtype='object'),
#  dtype('O'): Index(['ATS__c', 'Industry', 'employerId'], dtype='object')}

# %%
cat_col = ['ATS__c', 'Industry']

# %%
LabelMap = dict()
for i in cat_col:
    print('Start encoding ' + i)
    df_tmp = pd.concat([datatrain[i], datarun[i]])
    df_tmp = df_tmp.fillna('missing')
    le = LabelEncoder()
    le.fit(df_tmp)
    LabelMap[i] = dict(zip(le.classes_, le.transform(le.classes_)))
# Out:
# Start encoding ATS__c
# Start encoding Industry

# %%
for i in LabelMap:
    LabelMap[i]['missing'] = np.nan

LabelMap
# Out:
# {'ATS__c': {'ApplicantPro': 0,
#   'CustomCrawl': 1,
#   'EMPLOYER SOURCE': 2,
#   'HRM Direct': 3,
#   'Jobvite': 4,
#   'MyStaffingPro': 5,
#   'OpenHire (FTP Feed)': 6,
#   'SmartRecruiters': 7,
#   'UNKNOWN': 8,
#   'WorkableHR.com': 9,
#   'WorkforceNow': 10,
#   'app.theresumator.com': 11,
#   'greenhouse': 12,
#   'healthcareSource': 13,
#   'iCIMS Master Feed': 14,
#   'icims': 15,
#   'kenexaBrassRing': 16,
#   'missing': nan,
#   'neoGov': 17,
#   'other': 18,
#   'taleo': 19,
#   'tbe': 20,
#   'ultiRecruit': 21,
#   'workDay': 22},
#  'Industry': {'Accounting & Legal': 0,
#   'Advertising & Marketing': 1,
#   'Aerospace & Defense': 2,
#   'Agriculture & Forestry': 3,
#   'Arts, Entertainment & Recreation': 4,
#   'Biotech & Pharmaceuticals': 5,
#   'Business Services': 6,
#   'Computer Hardware & Software': 7,
#   'Construction, Repair & Maintenance': 8,
#   'Consumer Services': 9,
#   'Education': 10,
#   'Finance': 11,
#   'Government': 12,
#   'Health Care': 13,
#   'Information Technology': 14,
#   'Insurance': 15,
#   'Manufacturing': 16,
#   'Media': 17,
#   'Mining & Metals': 18,
#   'Non-Profit': 19,
#   'Oil, Gas, Energy & Utilities': 20,
#   'Other': 21,
#   'Real Estate': 22,
#   'Restaurants, Bars & Food Services': 23,
#   'Retail': 24,
#   'Telecommunications': 25,
#   'Transportation & Logistics': 26,
#   'Travel & Tourism': 27,
#   'UNKNOWN': 28,
#   'missing': nan}}

# %%
# Save Label Mapping
np.save('./input/LabelMapping.npy', LabelMap) 

# Load Label Mapping
# LabelMap = np.load('LabelMapping.npy').item()

# %%
datatrain.replace(LabelMap, inplace=True)
datarun.replace(LabelMap, inplace=True)

# %% [markdown]
# ## 3. Train/Test Data Split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# For the Train/Test Data Split, I use a 75%/25% ratio and stratified on "Industry".

# %%
train, test = train_test_split(datatrain, test_size=.25, train_size=.75, stratify=datatrain['Industry'].tolist(), random_state=111)
print(train.shape, test.shape)
# Out:
# (12675, 21) (4226, 21)

# %% [markdown]
# ## A. LightGBM Model
#
# I use [LightGBM](https://github.com/Microsoft/LightGBM) as the first model. LightGBM is a fast, distributed, high performance gradient boosting framework based on decision tree algorithms, used for ranking, classification and many other machine learning tasks. I use 5-fold cross validation to tune the parameters at first.

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV

# %%
# create dataset for lightgbm
X_train = train.drop(['isWon','employerId'], axis=1)
y_train = train['isWon']
X_test = test.drop(['isWon','employerId'], axis=1)
y_test = test['isWon']
lgb_train = lgb.Dataset(X_train, y_train, categorical_feature=cat_col)
lgb_eval = lgb.Dataset(X_test, y_test, categorical_feature=cat_col, reference=lgb_train)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': {'binary_logloss', 'auc'},
    'num_boost_round': 500,
    'learning_rate': .1,
    'num_leaves': 31,
    'max_bin': 255,
    'lambda_l2': .05,
    'num_threads':8
}

param_grid = {
    'boosting_type': ['gbdt'],
    'objective': ['binary'],
    'metric': ['binary_logloss'],
    'num_boost_round': [500],
    'learning_rate': [.1],
    'num_leaves': [20,30,50,70,90],
    'max_bin': [255,383,511],
    'lambda_l2': [0, .05, .1],
    'num_threads': [8]
}

mod = lgb.LGBMClassifier(boosting_type=params['boosting_type'],
                         objective=params['objective'],
                         metric=params['metric'],
                         num_boost_round=params['num_boost_round'],
                         learning_rate=params['learning_rate'],
                         num_leaves=params['num_leaves'],
                         max_bin=params['max_bin'],
                         lambda_l2=params['lambda_l2'],
                         num_threads=params['num_threads']
                       )

# %%
# %time
print('CV training start...')
grid = GridSearchCV(mod, param_grid, cv=5)
grid.fit(X_train, y_train)
# Out:
# Wall time: 0 ns
# CV training start...
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ...
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:99: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         lambda_l2=0.05, learning_rate=0.1, max_bin=255, max_depth=-1,
#         metric={'binary_logloss', 'auc'}, min_child_samples=20,
#         min_child_weight=0.001, min_split_gain=0.0, n_estimators=100,
#         ...     reg_lambda=0.0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=1),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'boosting_type': ['gbdt'], 'objective': ['binary'], 'metric': ['binary_logloss'], 'num_boost_round': [500], 'learning_rate': [0.1], 'num_leaves': [20, 30, 50, 70, 90], 'max_bin': [255, 383, 511], 'lambda_l2': [0, 0.05, 0.1], 'num_threads': [8]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
grid.best_params_
# Out:
# {'boosting_type': 'gbdt',
#  'lambda_l2': 0.05,
#  'learning_rate': 0.1,
#  'max_bin': 383,
#  'metric': 'binary_logloss',
#  'num_boost_round': 500,
#  'num_leaves': 20,
#  'num_threads': 8,
#  'objective': 'binary'}

# %%
# %%time
# specify your configurations as a dict
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': {'binary_logloss', 'auc'},
    'num_leaves': 30,
    'max_bin': 511,
    'learning_rate': 0.01,
    'verbose': 0,
    'num_threads':8,
    'early_stopping_round':100
}

print('Start training...')
# train
gbm = lgb.train(params,
                lgb_train,
                categorical_feature = cat_col,
                num_boost_round=10000,
                valid_sets=lgb_eval)

print('Save model...')
# save model to file
gbm.save_model('lgb_model.txt')
# Out:
# Start training...
# [1]	valid_0's binary_logloss: 0.686633	valid_0's auc: 0.7148
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.680251	valid_0's auc: 0.714822
# [3]	valid_0's binary_logloss: 0.673988	valid_0's auc: 0.715819
# [4]	valid_0's binary_logloss: 0.667837	valid_0's auc: 0.721986
# [5]	valid_0's binary_logloss: 0.661816	valid_0's auc: 0.72237
# [6]	valid_0's binary_logloss: 0.655916	valid_0's auc: 0.722281
# [7]	valid_0's binary_logloss: 0.650123	valid_0's auc: 0.722827
# [8]	valid_0's binary_logloss: 0.644448	valid_0's auc: 0.725233
# [9]	valid_0's binary_logloss: 0.638895	valid_0's auc: 0.726016
# [10]	valid_0's binary_logloss: 0.633421	valid_0's auc: 0.72663
# [11]	valid_0's binary_logloss: 0.628075	valid_0's auc: 0.727284
# [12]	valid_0's binary_logloss: 0.622823	valid_0's auc: 0.727531
# [13]	valid_0's binary_logloss: 0.617683	valid_0's auc: 0.727672
# [14]	valid_0's binary_logloss: 0.612605	valid_0's auc: 0.727902
# [15]	valid_0's binary_logloss: 0.60763	valid_0's auc: 0.732434
# [16]	valid_0's binary_logloss: 0.602767	valid_0's auc: 0.735198
# [17]	valid_0's binary_logloss: 0.597967	valid_0's auc: 0.735267
# [18]	valid_0's binary_logloss: 0.59327	valid_0's auc: 0.736507
# [19]	valid_0's binary_logloss: 0.588658	valid_0's auc: 0.735978
# [20]	valid_0's binary_logloss: 0.584131	valid_0's auc: 0.737028
# [21]	valid_0's binary_logloss: 0.57967	valid_0's auc: 0.736374
# [22]	valid_0's binary_logloss: 0.575304	valid_0's auc: 0.738704
# [23]	valid_0's binary_logloss: 0.57099	valid_0's auc: 0.738456
# [24]	valid_0's binary_logloss: 0.566795	valid_0's auc: 0.739336
# [25]	valid_0's binary_logloss: 0.562634	valid_0's auc: 0.738891
# [26]	valid_0's binary_logloss: 0.558557	valid_0's auc: 0.739367
# [27]	valid_0's binary_logloss: 0.554581	valid_0's auc: 0.739828
# [28]	valid_0's binary_logloss: 0.550623	valid_0's auc: 0.740075
# [29]	valid_0's binary_logloss: 0.546764	valid_0's auc: 0.740584
# [30]	valid_0's binary_logloss: 0.542948	valid_0's auc: 0.741854
# [31]	valid_0's binary_logloss: 0.539223	valid_0's auc: 0.742128
# [32]	valid_0's binary_logloss: 0.535541	valid_0's auc: 0.742769
# [33]	valid_0's binary_logloss: 0.531946	valid_0's auc: 0.742782
# [34]	valid_0's binary_logloss: 0.528361	valid_0's auc: 0.743028
# [35]	valid_0's binary_logloss: 0.524885	valid_0's auc: 0.74279
# [36]	valid_0's binary_logloss: 0.521454	valid_0's auc: 0.743026
# [37]	valid_0's binary_logloss: 0.518068	valid_0's auc: 0.743404
# [38]	valid_0's binary_logloss: 0.514742	valid_0's auc: 0.743298
# [39]	valid_0's binary_logloss: 0.511504	valid_0's auc: 0.743432
# [40]	valid_0's binary_logloss: 0.508289	valid_0's auc: 0.743786
# [41]	valid_0's binary_logloss: 0.50507	valid_0's auc: 0.744867
# [42]	valid_0's binary_logloss: 0.501964	valid_0's auc: 0.744761
# [43]	valid_0's binary_logloss: 0.498897	valid_0's auc: 0.745006
# [44]	valid_0's binary_logloss: 0.495885	valid_0's auc: 0.745014
# [45]	valid_0's binary_logloss: 0.492869	valid_0's auc: 0.745413
# [46]	valid_0's binary_logloss: 0.489949	valid_0's auc: 0.745518
# [47]	valid_0's binary_logloss: 0.487089	valid_0's auc: 0.745305
# [48]	valid_0's binary_logloss: 0.484255	valid_0's auc: 0.745613
# [49]	valid_0's binary_logloss: 0.481479	valid_0's auc: 0.745641
# [50]	valid_0's binary_logloss: 0.478716	valid_0's auc: 0.745913
# [51]	valid_0's binary_logloss: 0.476024	valid_0's auc: 0.745804
# [52]	valid_0's binary_logloss: 0.473382	valid_0's auc: 0.745702
# [53]	valid_0's binary_logloss: 0.470737	valid_0's auc: 0.745999
# [54]	valid_0's binary_logloss: 0.468171	valid_0's auc: 0.745762
# [55]	valid_0's binary_logloss: 0.465642	valid_0's auc: 0.745849
# [56]	valid_0's binary_logloss: 0.463117	valid_0's auc: 0.746233
# [57]	valid_0's binary_logloss: 0.4607	valid_0's auc: 0.7462
# [58]	valid_0's binary_logloss: 0.458229	valid_0's auc: 0.746814
# [59]	valid_0's binary_logloss: 0.455802	valid_0's auc: 0.747042
# [60]	valid_0's binary_logloss: 0.453441	valid_0's auc: 0.74707
# [61]	valid_0's binary_logloss: 0.451096	valid_0's auc: 0.747258
# [62]	valid_0's binary_logloss: 0.448778	valid_0's auc: 0.747574
# [63]	valid_0's binary_logloss: 0.44649	valid_0's auc: 0.747941
# [64]	valid_0's binary_logloss: 0.44429	valid_0's auc: 0.747894
# [65]	valid_0's binary_logloss: 0.442086	valid_0's auc: 0.748295
# [66]	valid_0's binary_logloss: 0.439912	valid_0's auc: 0.748467
# [67]	valid_0's binary_logloss: 0.437791	valid_0's auc: 0.748482
# [68]	valid_0's binary_logloss: 0.435694	valid_0's auc: 0.748667
# [69]	valid_0's binary_logloss: 0.433621	valid_0's auc: 0.748873
# [70]	valid_0's binary_logloss: 0.431554	valid_0's auc: 0.749121
# [71]	valid_0's binary_logloss: 0.429521	valid_0's auc: 0.749275
# [72]	valid_0's binary_logloss: 0.427519	valid_0's auc: 0.749439
# [73]	valid_0's binary_logloss: 0.425591	valid_0's auc: 0.749394
# [74]	valid_0's binary_logloss: 0.42367	valid_0's auc: 0.74987
# [75]	valid_0's binary_logloss: 0.421787	valid_0's auc: 0.75027
# [76]	valid_0's binary_logloss: 0.419939	valid_0's auc: 0.750341
# [77]	valid_0's binary_logloss: 0.418124	valid_0's auc: 0.750401
# [78]	valid_0's binary_logloss: 0.416284	valid_0's auc: 0.750948
# [79]	valid_0's binary_logloss: 0.41447	valid_0's auc: 0.751189
# [80]	valid_0's binary_logloss: 0.412711	valid_0's auc: 0.751573
# [81]	valid_0's binary_logloss: 0.410948	valid_0's auc: 0.751888
# [82]	valid_0's binary_logloss: 0.409225	valid_0's auc: 0.752225
# [83]	valid_0's binary_logloss: 0.40753	valid_0's auc: 0.75236
# [84]	valid_0's binary_logloss: 0.405886	valid_0's auc: 0.752545
# [85]	valid_0's binary_logloss: 0.404235	valid_0's auc: 0.75249
# [86]	valid_0's binary_logloss: 0.402614	valid_0's auc: 0.752555
# [87]	valid_0's binary_logloss: 0.401031	valid_0's auc: 0.752588
# [88]	valid_0's binary_logloss: 0.399464	valid_0's auc: 0.75263
# [89]	valid_0's binary_logloss: 0.397924	valid_0's auc: 0.752797
# [90]	valid_0's binary_logloss: 0.396382	valid_0's auc: 0.753171
# [91]	valid_0's binary_logloss: 0.394873	valid_0's auc: 0.753378
# [92]	valid_0's binary_logloss: 0.393397	valid_0's auc: 0.753515
# [93]	valid_0's binary_logloss: 0.391946	valid_0's auc: 0.753732
# [94]	valid_0's binary_logloss: 0.390509	valid_0's auc: 0.753847
# [95]	valid_0's binary_logloss: 0.389075	valid_0's auc: 0.754039
# [96]	valid_0's binary_logloss: 0.387669	valid_0's auc: 0.754265
# [97]	valid_0's binary_logloss: 0.386314	valid_0's auc: 0.754266
# [98]	valid_0's binary_logloss: 0.384952	valid_0's auc: 0.754449
# [99]	valid_0's binary_logloss: 0.383641	valid_0's auc: 0.754394
# [100]	valid_0's binary_logloss: 0.382314	valid_0's auc: 0.754583
# [101]	valid_0's binary_logloss: 0.381015	valid_0's auc: 0.75486
# [102]	valid_0's binary_logloss: 0.379721	valid_0's auc: 0.755045
# [103]	valid_0's binary_logloss: 0.378474	valid_0's auc: 0.754951
# [104]	valid_0's binary_logloss: 0.377218	valid_0's auc: 0.755067
# [105]	valid_0's binary_logloss: 0.375996	valid_0's auc: 0.755095
# [106]	valid_0's binary_logloss: 0.374806	valid_0's auc: 0.755158
# [107]	valid_0's binary_logloss: 0.373592	valid_0's auc: 0.75512
# [108]	valid_0's binary_logloss: 0.372433	valid_0's auc: 0.755174
# [109]	valid_0's binary_logloss: 0.371282	valid_0's auc: 0.75506
# [110]	valid_0's binary_logloss: 0.370141	valid_0's auc: 0.755354
# [111]	valid_0's binary_logloss: 0.36902	valid_0's auc: 0.755507
# [112]	valid_0's binary_logloss: 0.367909	valid_0's auc: 0.755534
# [113]	valid_0's binary_logloss: 0.366837	valid_0's auc: 0.755554
# [114]	valid_0's binary_logloss: 0.365752	valid_0's auc: 0.755618
# [115]	valid_0's binary_logloss: 0.364679	valid_0's auc: 0.755702
# [116]	valid_0's binary_logloss: 0.363661	valid_0's auc: 0.755505
# [117]	valid_0's binary_logloss: 0.362609	valid_0's auc: 0.755693
# [118]	valid_0's binary_logloss: 0.361586	valid_0's auc: 0.755738
# E:\Anaconda3\lib\site-packages\lightgbm\engine.py:104: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\Anaconda3\lib\site-packages\lightgbm\basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# [119]	valid_0's binary_logloss: 0.360589	valid_0's auc: 0.755938
# [120]	valid_0's binary_logloss: 0.359633	valid_0's auc: 0.755882
# [121]	valid_0's binary_logloss: 0.358661	valid_0's auc: 0.756048
# [122]	valid_0's binary_logloss: 0.357687	valid_0's auc: 0.756182
# [123]	valid_0's binary_logloss: 0.35675	valid_0's auc: 0.756232
# [124]	valid_0's binary_logloss: 0.355814	valid_0's auc: 0.756338
# [125]	valid_0's binary_logloss: 0.35491	valid_0's auc: 0.756387
# [126]	valid_0's binary_logloss: 0.354015	valid_0's auc: 0.756453
# [127]	valid_0's binary_logloss: 0.353161	valid_0's auc: 0.756288
# [128]	valid_0's binary_logloss: 0.352314	valid_0's auc: 0.756156
# [129]	valid_0's binary_logloss: 0.351453	valid_0's auc: 0.7562
# [130]	valid_0's binary_logloss: 0.350575	valid_0's auc: 0.757377
# [131]	valid_0's binary_logloss: 0.349729	valid_0's auc: 0.757463
# [132]	valid_0's binary_logloss: 0.348899	valid_0's auc: 0.757572
# [133]	valid_0's binary_logloss: 0.348084	valid_0's auc: 0.757483
# [134]	valid_0's binary_logloss: 0.347292	valid_0's auc: 0.757526
# [135]	valid_0's binary_logloss: 0.346492	valid_0's auc: 0.757722
# [136]	valid_0's binary_logloss: 0.345692	valid_0's auc: 0.757967
# [137]	valid_0's binary_logloss: 0.34493	valid_0's auc: 0.758087
# [138]	valid_0's binary_logloss: 0.344156	valid_0's auc: 0.75825
# [139]	valid_0's binary_logloss: 0.343438	valid_0's auc: 0.758131
# [140]	valid_0's binary_logloss: 0.342685	valid_0's auc: 0.758274
# [141]	valid_0's binary_logloss: 0.341929	valid_0's auc: 0.75835
# [142]	valid_0's binary_logloss: 0.341187	valid_0's auc: 0.758282
# [143]	valid_0's binary_logloss: 0.34046	valid_0's auc: 0.758416
# [144]	valid_0's binary_logloss: 0.339732	valid_0's auc: 0.758576
# [145]	valid_0's binary_logloss: 0.33905	valid_0's auc: 0.758559
# [146]	valid_0's binary_logloss: 0.338359	valid_0's auc: 0.758654
# [147]	valid_0's binary_logloss: 0.337676	valid_0's auc: 0.758746
# [148]	valid_0's binary_logloss: 0.337001	valid_0's auc: 0.758916
# [149]	valid_0's binary_logloss: 0.336326	valid_0's auc: 0.759113
# [150]	valid_0's binary_logloss: 0.335671	valid_0's auc: 0.759161
# [151]	valid_0's binary_logloss: 0.335036	valid_0's auc: 0.759166
# [152]	valid_0's binary_logloss: 0.33439	valid_0's auc: 0.759378
# [153]	valid_0's binary_logloss: 0.333749	valid_0's auc: 0.759366
# [154]	valid_0's binary_logloss: 0.333122	valid_0's auc: 0.759538
# [155]	valid_0's binary_logloss: 0.332491	valid_0's auc: 0.759632
# [156]	valid_0's binary_logloss: 0.33188	valid_0's auc: 0.759653
# [157]	valid_0's binary_logloss: 0.331304	valid_0's auc: 0.759632
# [158]	valid_0's binary_logloss: 0.330668	valid_0's auc: 0.75985
# [159]	valid_0's binary_logloss: 0.330046	valid_0's auc: 0.760001
# [160]	valid_0's binary_logloss: 0.329482	valid_0's auc: 0.760028
# [161]	valid_0's binary_logloss: 0.328883	valid_0's auc: 0.760191
# [162]	valid_0's binary_logloss: 0.328318	valid_0's auc: 0.760146
# [163]	valid_0's binary_logloss: 0.327761	valid_0's auc: 0.760471
# [164]	valid_0's binary_logloss: 0.327199	valid_0's auc: 0.760669
# [165]	valid_0's binary_logloss: 0.326658	valid_0's auc: 0.760564
# [166]	valid_0's binary_logloss: 0.326117	valid_0's auc: 0.76077
# [167]	valid_0's binary_logloss: 0.325586	valid_0's auc: 0.760741
# [168]	valid_0's binary_logloss: 0.325074	valid_0's auc: 0.761052
# [169]	valid_0's binary_logloss: 0.324547	valid_0's auc: 0.76126
# [170]	valid_0's binary_logloss: 0.324053	valid_0's auc: 0.761254
# [171]	valid_0's binary_logloss: 0.323544	valid_0's auc: 0.761453
# [172]	valid_0's binary_logloss: 0.323059	valid_0's auc: 0.761676
# [173]	valid_0's binary_logloss: 0.322558	valid_0's auc: 0.76185
# [174]	valid_0's binary_logloss: 0.322037	valid_0's auc: 0.762301
# [175]	valid_0's binary_logloss: 0.321577	valid_0's auc: 0.76231
# [176]	valid_0's binary_logloss: 0.321118	valid_0's auc: 0.762429
# [177]	valid_0's binary_logloss: 0.320655	valid_0's auc: 0.762671
# [178]	valid_0's binary_logloss: 0.32022	valid_0's auc: 0.762659
# [179]	valid_0's binary_logloss: 0.319762	valid_0's auc: 0.762716
# [180]	valid_0's binary_logloss: 0.319302	valid_0's auc: 0.763026
# [181]	valid_0's binary_logloss: 0.318877	valid_0's auc: 0.763161
# [182]	valid_0's binary_logloss: 0.318436	valid_0's auc: 0.76345
# [183]	valid_0's binary_logloss: 0.318001	valid_0's auc: 0.763628
# [184]	valid_0's binary_logloss: 0.31756	valid_0's auc: 0.763606
# [185]	valid_0's binary_logloss: 0.317161	valid_0's auc: 0.763641
# [186]	valid_0's binary_logloss: 0.31675	valid_0's auc: 0.763774
# [187]	valid_0's binary_logloss: 0.316334	valid_0's auc: 0.76401
# [188]	valid_0's binary_logloss: 0.315925	valid_0's auc: 0.764248
# [189]	valid_0's binary_logloss: 0.315558	valid_0's auc: 0.764194
# [190]	valid_0's binary_logloss: 0.315177	valid_0's auc: 0.764324
# [191]	valid_0's binary_logloss: 0.314771	valid_0's auc: 0.76437
# [192]	valid_0's binary_logloss: 0.314418	valid_0's auc: 0.764426
# [193]	valid_0's binary_logloss: 0.314019	valid_0's auc: 0.764676
# [194]	valid_0's binary_logloss: 0.313658	valid_0's auc: 0.764711
# [195]	valid_0's binary_logloss: 0.313291	valid_0's auc: 0.76464
# [196]	valid_0's binary_logloss: 0.312895	valid_0's auc: 0.765069
# [197]	valid_0's binary_logloss: 0.312537	valid_0's auc: 0.765156
# [198]	valid_0's binary_logloss: 0.312184	valid_0's auc: 0.765254
# [199]	valid_0's binary_logloss: 0.311833	valid_0's auc: 0.76526
# [200]	valid_0's binary_logloss: 0.311458	valid_0's auc: 0.765591
# [201]	valid_0's binary_logloss: 0.311108	valid_0's auc: 0.765801
# [202]	valid_0's binary_logloss: 0.310804	valid_0's auc: 0.765804
# [203]	valid_0's binary_logloss: 0.310452	valid_0's auc: 0.766013
# [204]	valid_0's binary_logloss: 0.31016	valid_0's auc: 0.76601
# [205]	valid_0's binary_logloss: 0.309871	valid_0's auc: 0.766029
# [206]	valid_0's binary_logloss: 0.309543	valid_0's auc: 0.766121
# [207]	valid_0's binary_logloss: 0.309264	valid_0's auc: 0.766166
# [208]	valid_0's binary_logloss: 0.308955	valid_0's auc: 0.766256
# [209]	valid_0's binary_logloss: 0.308679	valid_0's auc: 0.766224
# [210]	valid_0's binary_logloss: 0.308416	valid_0's auc: 0.766268
# [211]	valid_0's binary_logloss: 0.308111	valid_0's auc: 0.766412
# [212]	valid_0's binary_logloss: 0.307799	valid_0's auc: 0.766591
# [213]	valid_0's binary_logloss: 0.307551	valid_0's auc: 0.766532
# [214]	valid_0's binary_logloss: 0.307247	valid_0's auc: 0.766704
# [215]	valid_0's binary_logloss: 0.306995	valid_0's auc: 0.766655
# [216]	valid_0's binary_logloss: 0.306709	valid_0's auc: 0.766701
# [217]	valid_0's binary_logloss: 0.306473	valid_0's auc: 0.766635
# [218]	valid_0's binary_logloss: 0.306197	valid_0's auc: 0.766746
# [219]	valid_0's binary_logloss: 0.305934	valid_0's auc: 0.766846
# [220]	valid_0's binary_logloss: 0.305697	valid_0's auc: 0.766913
# [221]	valid_0's binary_logloss: 0.305401	valid_0's auc: 0.767052
# [222]	valid_0's binary_logloss: 0.305154	valid_0's auc: 0.767146
# [223]	valid_0's binary_logloss: 0.304906	valid_0's auc: 0.767233
# [224]	valid_0's binary_logloss: 0.304665	valid_0's auc: 0.767258
# [225]	valid_0's binary_logloss: 0.30445	valid_0's auc: 0.767205
# [226]	valid_0's binary_logloss: 0.304181	valid_0's auc: 0.767346
# [227]	valid_0's binary_logloss: 0.30391	valid_0's auc: 0.767489
# [228]	valid_0's binary_logloss: 0.303678	valid_0's auc: 0.767554
# [229]	valid_0's binary_logloss: 0.303457	valid_0's auc: 0.767575
# [230]	valid_0's binary_logloss: 0.303238	valid_0's auc: 0.767629
# [231]	valid_0's binary_logloss: 0.30302	valid_0's auc: 0.767748
# [232]	valid_0's binary_logloss: 0.302794	valid_0's auc: 0.767711
# [233]	valid_0's binary_logloss: 0.302574	valid_0's auc: 0.767786
# [234]	valid_0's binary_logloss: 0.302344	valid_0's auc: 0.768048
# [235]	valid_0's binary_logloss: 0.302113	valid_0's auc: 0.768081
# [236]	valid_0's binary_logloss: 0.301908	valid_0's auc: 0.768079
# [237]	valid_0's binary_logloss: 0.3017	valid_0's auc: 0.768188
# [238]	valid_0's binary_logloss: 0.301495	valid_0's auc: 0.768255
# [239]	valid_0's binary_logloss: 0.301294	valid_0's auc: 0.768253
# [240]	valid_0's binary_logloss: 0.301089	valid_0's auc: 0.768402
# [241]	valid_0's binary_logloss: 0.300904	valid_0's auc: 0.768459
# [242]	valid_0's binary_logloss: 0.300754	valid_0's auc: 0.768296
# [243]	valid_0's binary_logloss: 0.300556	valid_0's auc: 0.768311
# [244]	valid_0's binary_logloss: 0.300358	valid_0's auc: 0.768348
# [245]	valid_0's binary_logloss: 0.300194	valid_0's auc: 0.768342
# [246]	valid_0's binary_logloss: 0.299993	valid_0's auc: 0.7684
# [247]	valid_0's binary_logloss: 0.299849	valid_0's auc: 0.768334
# [248]	valid_0's binary_logloss: 0.299664	valid_0's auc: 0.768393
# [249]	valid_0's binary_logloss: 0.299503	valid_0's auc: 0.768449
# [250]	valid_0's binary_logloss: 0.299342	valid_0's auc: 0.768512
# [251]	valid_0's binary_logloss: 0.299183	valid_0's auc: 0.768522
# [252]	valid_0's binary_logloss: 0.29902	valid_0's auc: 0.768555
# [253]	valid_0's binary_logloss: 0.2989	valid_0's auc: 0.768366
# [254]	valid_0's binary_logloss: 0.2987	valid_0's auc: 0.768444
# [255]	valid_0's binary_logloss: 0.298537	valid_0's auc: 0.768439
# [256]	valid_0's binary_logloss: 0.298403	valid_0's auc: 0.768435
# [257]	valid_0's binary_logloss: 0.298237	valid_0's auc: 0.768508
# [258]	valid_0's binary_logloss: 0.298101	valid_0's auc: 0.768406
# [259]	valid_0's binary_logloss: 0.29795	valid_0's auc: 0.768512
# [260]	valid_0's binary_logloss: 0.297834	valid_0's auc: 0.768485
# [261]	valid_0's binary_logloss: 0.297675	valid_0's auc: 0.768594
# [262]	valid_0's binary_logloss: 0.297515	valid_0's auc: 0.768645
# [263]	valid_0's binary_logloss: 0.297359	valid_0's auc: 0.768758
# [264]	valid_0's binary_logloss: 0.297204	valid_0's auc: 0.76884
# [265]	valid_0's binary_logloss: 0.29705	valid_0's auc: 0.768868
# [266]	valid_0's binary_logloss: 0.296893	valid_0's auc: 0.768958
# [267]	valid_0's binary_logloss: 0.296741	valid_0's auc: 0.76902
# [268]	valid_0's binary_logloss: 0.296653	valid_0's auc: 0.768871
# [269]	valid_0's binary_logloss: 0.296514	valid_0's auc: 0.768937
# [270]	valid_0's binary_logloss: 0.296389	valid_0's auc: 0.768957
# [271]	valid_0's binary_logloss: 0.296271	valid_0's auc: 0.769816
# [272]	valid_0's binary_logloss: 0.296136	valid_0's auc: 0.769956
# [273]	valid_0's binary_logloss: 0.296018	valid_0's auc: 0.770149
# [274]	valid_0's binary_logloss: 0.295884	valid_0's auc: 0.770197
# [275]	valid_0's binary_logloss: 0.295778	valid_0's auc: 0.770106
# [276]	valid_0's binary_logloss: 0.295661	valid_0's auc: 0.770134
# [277]	valid_0's binary_logloss: 0.295536	valid_0's auc: 0.770168
# [278]	valid_0's binary_logloss: 0.295409	valid_0's auc: 0.770198
# [279]	valid_0's binary_logloss: 0.295305	valid_0's auc: 0.770145
# [280]	valid_0's binary_logloss: 0.295196	valid_0's auc: 0.770825
# [281]	valid_0's binary_logloss: 0.29508	valid_0's auc: 0.770915
# [282]	valid_0's binary_logloss: 0.294958	valid_0's auc: 0.770706
# [283]	valid_0's binary_logloss: 0.294854	valid_0's auc: 0.770728
# [284]	valid_0's binary_logloss: 0.294733	valid_0's auc: 0.770836
# [285]	valid_0's binary_logloss: 0.294605	valid_0's auc: 0.770901
# [286]	valid_0's binary_logloss: 0.294487	valid_0's auc: 0.771019
# [287]	valid_0's binary_logloss: 0.294387	valid_0's auc: 0.770926
# [288]	valid_0's binary_logloss: 0.294295	valid_0's auc: 0.770907
# [289]	valid_0's binary_logloss: 0.294191	valid_0's auc: 0.77099
# [290]	valid_0's binary_logloss: 0.294046	valid_0's auc: 0.771185
# [291]	valid_0's binary_logloss: 0.29398	valid_0's auc: 0.771105
# [292]	valid_0's binary_logloss: 0.293873	valid_0's auc: 0.771163
# [293]	valid_0's binary_logloss: 0.293778	valid_0's auc: 0.771193
# [294]	valid_0's binary_logloss: 0.293672	valid_0's auc: 0.771292
# [295]	valid_0's binary_logloss: 0.293562	valid_0's auc: 0.771323
# [296]	valid_0's binary_logloss: 0.293492	valid_0's auc: 0.771255
# [297]	valid_0's binary_logloss: 0.293404	valid_0's auc: 0.771194
# [298]	valid_0's binary_logloss: 0.293291	valid_0's auc: 0.771311
# [299]	valid_0's binary_logloss: 0.293194	valid_0's auc: 0.771349
# [300]	valid_0's binary_logloss: 0.293111	valid_0's auc: 0.771359
# [301]	valid_0's binary_logloss: 0.292994	valid_0's auc: 0.771537
# [302]	valid_0's binary_logloss: 0.292918	valid_0's auc: 0.771721
# [303]	valid_0's binary_logloss: 0.292849	valid_0's auc: 0.771776
# [304]	valid_0's binary_logloss: 0.292768	valid_0's auc: 0.771762
# [305]	valid_0's binary_logloss: 0.292694	valid_0's auc: 0.771762
# [306]	valid_0's binary_logloss: 0.292604	valid_0's auc: 0.771678
# [307]	valid_0's binary_logloss: 0.292533	valid_0's auc: 0.771683
# [308]	valid_0's binary_logloss: 0.292439	valid_0's auc: 0.771937
# [309]	valid_0's binary_logloss: 0.292354	valid_0's auc: 0.771954
# [310]	valid_0's binary_logloss: 0.292292	valid_0's auc: 0.771916
# [311]	valid_0's binary_logloss: 0.292181	valid_0's auc: 0.772071
# [312]	valid_0's binary_logloss: 0.292123	valid_0's auc: 0.77194
# [313]	valid_0's binary_logloss: 0.292039	valid_0's auc: 0.772023
# [314]	valid_0's binary_logloss: 0.291957	valid_0's auc: 0.772303
# [315]	valid_0's binary_logloss: 0.291923	valid_0's auc: 0.772166
# [316]	valid_0's binary_logloss: 0.291771	valid_0's auc: 0.772479
# [317]	valid_0's binary_logloss: 0.291739	valid_0's auc: 0.772441
# [318]	valid_0's binary_logloss: 0.291686	valid_0's auc: 0.772516
# [319]	valid_0's binary_logloss: 0.291644	valid_0's auc: 0.772534
# [320]	valid_0's binary_logloss: 0.291598	valid_0's auc: 0.772452
# [321]	valid_0's binary_logloss: 0.291531	valid_0's auc: 0.772561
# [322]	valid_0's binary_logloss: 0.291465	valid_0's auc: 0.772622
# [323]	valid_0's binary_logloss: 0.291388	valid_0's auc: 0.772722
# [324]	valid_0's binary_logloss: 0.291345	valid_0's auc: 0.77264
# [325]	valid_0's binary_logloss: 0.291293	valid_0's auc: 0.772578
# [326]	valid_0's binary_logloss: 0.291252	valid_0's auc: 0.772541
# [327]	valid_0's binary_logloss: 0.29121	valid_0's auc: 0.772454
# [328]	valid_0's binary_logloss: 0.291157	valid_0's auc: 0.772442
# [329]	valid_0's binary_logloss: 0.291075	valid_0's auc: 0.772582
# [330]	valid_0's binary_logloss: 0.29105	valid_0's auc: 0.772054
# [331]	valid_0's binary_logloss: 0.290981	valid_0's auc: 0.772169
# [332]	valid_0's binary_logloss: 0.290945	valid_0's auc: 0.772079
# [333]	valid_0's binary_logloss: 0.29088	valid_0's auc: 0.772173
# [334]	valid_0's binary_logloss: 0.290856	valid_0's auc: 0.772073
# [335]	valid_0's binary_logloss: 0.290805	valid_0's auc: 0.772148
# [336]	valid_0's binary_logloss: 0.290754	valid_0's auc: 0.772156
# [337]	valid_0's binary_logloss: 0.290678	valid_0's auc: 0.772313
# [338]	valid_0's binary_logloss: 0.290647	valid_0's auc: 0.772177
# [339]	valid_0's binary_logloss: 0.290566	valid_0's auc: 0.772253
# [340]	valid_0's binary_logloss: 0.290531	valid_0's auc: 0.772211
# [341]	valid_0's binary_logloss: 0.290463	valid_0's auc: 0.772305
# [342]	valid_0's binary_logloss: 0.290389	valid_0's auc: 0.772371
# [343]	valid_0's binary_logloss: 0.290347	valid_0's auc: 0.772406
# [344]	valid_0's binary_logloss: 0.290282	valid_0's auc: 0.772421
# [345]	valid_0's binary_logloss: 0.290229	valid_0's auc: 0.772443
# [346]	valid_0's binary_logloss: 0.290187	valid_0's auc: 0.772596
# [347]	valid_0's binary_logloss: 0.290149	valid_0's auc: 0.772569
# [348]	valid_0's binary_logloss: 0.290077	valid_0's auc: 0.772682
# [349]	valid_0's binary_logloss: 0.290028	valid_0's auc: 0.772752
# [350]	valid_0's binary_logloss: 0.289989	valid_0's auc: 0.772702
# [351]	valid_0's binary_logloss: 0.28994	valid_0's auc: 0.772714
# [352]	valid_0's binary_logloss: 0.289915	valid_0's auc: 0.772721
# [353]	valid_0's binary_logloss: 0.289892	valid_0's auc: 0.772439
# [354]	valid_0's binary_logloss: 0.289875	valid_0's auc: 0.772402
# [355]	valid_0's binary_logloss: 0.289817	valid_0's auc: 0.772516
# [356]	valid_0's binary_logloss: 0.28981	valid_0's auc: 0.772339
# [357]	valid_0's binary_logloss: 0.28972	valid_0's auc: 0.772541
# [358]	valid_0's binary_logloss: 0.289631	valid_0's auc: 0.772728
# [359]	valid_0's binary_logloss: 0.289578	valid_0's auc: 0.77269
# [360]	valid_0's binary_logloss: 0.289531	valid_0's auc: 0.772664
# [361]	valid_0's binary_logloss: 0.289479	valid_0's auc: 0.772656
# [362]	valid_0's binary_logloss: 0.289463	valid_0's auc: 0.7726
# [363]	valid_0's binary_logloss: 0.289412	valid_0's auc: 0.772636
# [364]	valid_0's binary_logloss: 0.289389	valid_0's auc: 0.772591
# [365]	valid_0's binary_logloss: 0.28934	valid_0's auc: 0.772705
# [366]	valid_0's binary_logloss: 0.28932	valid_0's auc: 0.772604
# [367]	valid_0's binary_logloss: 0.28931	valid_0's auc: 0.772644
# [368]	valid_0's binary_logloss: 0.289266	valid_0's auc: 0.772657
# [369]	valid_0's binary_logloss: 0.289226	valid_0's auc: 0.772737
# [370]	valid_0's binary_logloss: 0.289202	valid_0's auc: 0.772677
# [371]	valid_0's binary_logloss: 0.289185	valid_0's auc: 0.772591
# [372]	valid_0's binary_logloss: 0.289151	valid_0's auc: 0.772708
# [373]	valid_0's binary_logloss: 0.289092	valid_0's auc: 0.772752
# [374]	valid_0's binary_logloss: 0.289058	valid_0's auc: 0.772808
# [375]	valid_0's binary_logloss: 0.289027	valid_0's auc: 0.772887
# [376]	valid_0's binary_logloss: 0.288973	valid_0's auc: 0.772939
# [377]	valid_0's binary_logloss: 0.288957	valid_0's auc: 0.772961
# [378]	valid_0's binary_logloss: 0.288901	valid_0's auc: 0.773178
# [379]	valid_0's binary_logloss: 0.288874	valid_0's auc: 0.773177
# [380]	valid_0's binary_logloss: 0.288849	valid_0's auc: 0.77316
# [381]	valid_0's binary_logloss: 0.288811	valid_0's auc: 0.773225
# [382]	valid_0's binary_logloss: 0.288807	valid_0's auc: 0.773153
# [383]	valid_0's binary_logloss: 0.28878	valid_0's auc: 0.773228
# [384]	valid_0's binary_logloss: 0.288754	valid_0's auc: 0.773265
# [385]	valid_0's binary_logloss: 0.288717	valid_0's auc: 0.773388
# [386]	valid_0's binary_logloss: 0.28869	valid_0's auc: 0.773398
# [387]	valid_0's binary_logloss: 0.288645	valid_0's auc: 0.773436
# [388]	valid_0's binary_logloss: 0.28862	valid_0's auc: 0.773435
# [389]	valid_0's binary_logloss: 0.288598	valid_0's auc: 0.773504
# [390]	valid_0's binary_logloss: 0.288568	valid_0's auc: 0.773567
# [391]	valid_0's binary_logloss: 0.288539	valid_0's auc: 0.77356
# [392]	valid_0's binary_logloss: 0.288498	valid_0's auc: 0.773605
# [393]	valid_0's binary_logloss: 0.288462	valid_0's auc: 0.773676
# [394]	valid_0's binary_logloss: 0.288437	valid_0's auc: 0.773679
# [395]	valid_0's binary_logloss: 0.288394	valid_0's auc: 0.773789
# [396]	valid_0's binary_logloss: 0.288396	valid_0's auc: 0.773736
# [397]	valid_0's binary_logloss: 0.28833	valid_0's auc: 0.77402
# [398]	valid_0's binary_logloss: 0.288277	valid_0's auc: 0.774098
# [399]	valid_0's binary_logloss: 0.288256	valid_0's auc: 0.774102
# [400]	valid_0's binary_logloss: 0.288231	valid_0's auc: 0.774149
# [401]	valid_0's binary_logloss: 0.288214	valid_0's auc: 0.774133
# [402]	valid_0's binary_logloss: 0.288208	valid_0's auc: 0.774083
# [403]	valid_0's binary_logloss: 0.288159	valid_0's auc: 0.774195
# [404]	valid_0's binary_logloss: 0.288136	valid_0's auc: 0.774253
# [405]	valid_0's binary_logloss: 0.288103	valid_0's auc: 0.774248
# [406]	valid_0's binary_logloss: 0.288066	valid_0's auc: 0.774321
# [407]	valid_0's binary_logloss: 0.28805	valid_0's auc: 0.774295
# [408]	valid_0's binary_logloss: 0.288006	valid_0's auc: 0.774385
# [409]	valid_0's binary_logloss: 0.287974	valid_0's auc: 0.774468
# [410]	valid_0's binary_logloss: 0.287942	valid_0's auc: 0.774516
# [411]	valid_0's binary_logloss: 0.287889	valid_0's auc: 0.774647
# [412]	valid_0's binary_logloss: 0.287808	valid_0's auc: 0.774797
# [413]	valid_0's binary_logloss: 0.287775	valid_0's auc: 0.774871
# [414]	valid_0's binary_logloss: 0.287792	valid_0's auc: 0.774784
# [415]	valid_0's binary_logloss: 0.287739	valid_0's auc: 0.774912
# [416]	valid_0's binary_logloss: 0.287704	valid_0's auc: 0.77501
# [417]	valid_0's binary_logloss: 0.287701	valid_0's auc: 0.774964
# [418]	valid_0's binary_logloss: 0.287624	valid_0's auc: 0.775104
# [419]	valid_0's binary_logloss: 0.287592	valid_0's auc: 0.775142
# [420]	valid_0's binary_logloss: 0.287539	valid_0's auc: 0.775307
# [421]	valid_0's binary_logloss: 0.287512	valid_0's auc: 0.775335
# [422]	valid_0's binary_logloss: 0.287469	valid_0's auc: 0.775385
# [423]	valid_0's binary_logloss: 0.287439	valid_0's auc: 0.775483
# [424]	valid_0's binary_logloss: 0.287421	valid_0's auc: 0.775436
# [425]	valid_0's binary_logloss: 0.287347	valid_0's auc: 0.775556
# [426]	valid_0's binary_logloss: 0.287334	valid_0's auc: 0.775565
# [427]	valid_0's binary_logloss: 0.287286	valid_0's auc: 0.775613
# [428]	valid_0's binary_logloss: 0.287235	valid_0's auc: 0.775694
# [429]	valid_0's binary_logloss: 0.287238	valid_0's auc: 0.775617
# [430]	valid_0's binary_logloss: 0.287183	valid_0's auc: 0.775736
# [431]	valid_0's binary_logloss: 0.287163	valid_0's auc: 0.775827
# [432]	valid_0's binary_logloss: 0.287158	valid_0's auc: 0.775798
# [433]	valid_0's binary_logloss: 0.287145	valid_0's auc: 0.775742
# [434]	valid_0's binary_logloss: 0.287102	valid_0's auc: 0.77582
# [435]	valid_0's binary_logloss: 0.28706	valid_0's auc: 0.775845
# [436]	valid_0's binary_logloss: 0.287016	valid_0's auc: 0.775875
# [437]	valid_0's binary_logloss: 0.286957	valid_0's auc: 0.776014
# [438]	valid_0's binary_logloss: 0.2869	valid_0's auc: 0.776066
# [439]	valid_0's binary_logloss: 0.286861	valid_0's auc: 0.776096
# [440]	valid_0's binary_logloss: 0.286825	valid_0's auc: 0.776148
# [441]	valid_0's binary_logloss: 0.286766	valid_0's auc: 0.776224
# [442]	valid_0's binary_logloss: 0.286758	valid_0's auc: 0.776177
# [443]	valid_0's binary_logloss: 0.286703	valid_0's auc: 0.776266
# [444]	valid_0's binary_logloss: 0.28671	valid_0's auc: 0.776233
# [445]	valid_0's binary_logloss: 0.286671	valid_0's auc: 0.776324
# [446]	valid_0's binary_logloss: 0.286609	valid_0's auc: 0.77643
# [447]	valid_0's binary_logloss: 0.286592	valid_0's auc: 0.776457
# [448]	valid_0's binary_logloss: 0.286534	valid_0's auc: 0.776509
# [449]	valid_0's binary_logloss: 0.286496	valid_0's auc: 0.776588
# [450]	valid_0's binary_logloss: 0.286447	valid_0's auc: 0.77667
# [451]	valid_0's binary_logloss: 0.286403	valid_0's auc: 0.776759
# [452]	valid_0's binary_logloss: 0.286367	valid_0's auc: 0.776854
# [453]	valid_0's binary_logloss: 0.286368	valid_0's auc: 0.776815
# [454]	valid_0's binary_logloss: 0.286334	valid_0's auc: 0.776868
# [455]	valid_0's binary_logloss: 0.28628	valid_0's auc: 0.776985
# [456]	valid_0's binary_logloss: 0.286232	valid_0's auc: 0.777078
# [457]	valid_0's binary_logloss: 0.286208	valid_0's auc: 0.777065
# [458]	valid_0's binary_logloss: 0.286211	valid_0's auc: 0.777022
# [459]	valid_0's binary_logloss: 0.286225	valid_0's auc: 0.776978
# [460]	valid_0's binary_logloss: 0.28616	valid_0's auc: 0.77712
# [461]	valid_0's binary_logloss: 0.286112	valid_0's auc: 0.777218
# [462]	valid_0's binary_logloss: 0.286119	valid_0's auc: 0.777122
# [463]	valid_0's binary_logloss: 0.28611	valid_0's auc: 0.777112
# [464]	valid_0's binary_logloss: 0.286096	valid_0's auc: 0.77711
# [465]	valid_0's binary_logloss: 0.286059	valid_0's auc: 0.777161
# [466]	valid_0's binary_logloss: 0.286022	valid_0's auc: 0.777257
# [467]	valid_0's binary_logloss: 0.285989	valid_0's auc: 0.77726
# [468]	valid_0's binary_logloss: 0.285982	valid_0's auc: 0.777245
# [469]	valid_0's binary_logloss: 0.285964	valid_0's auc: 0.777263
# [470]	valid_0's binary_logloss: 0.2859	valid_0's auc: 0.777452
# [471]	valid_0's binary_logloss: 0.285888	valid_0's auc: 0.77743
# [472]	valid_0's binary_logloss: 0.28585	valid_0's auc: 0.777526
# [473]	valid_0's binary_logloss: 0.285817	valid_0's auc: 0.777583
# [474]	valid_0's binary_logloss: 0.285773	valid_0's auc: 0.777635
# [475]	valid_0's binary_logloss: 0.285763	valid_0's auc: 0.777654
# [476]	valid_0's binary_logloss: 0.2857	valid_0's auc: 0.777821
# [477]	valid_0's binary_logloss: 0.285705	valid_0's auc: 0.777811
# [478]	valid_0's binary_logloss: 0.285694	valid_0's auc: 0.777794
# [479]	valid_0's binary_logloss: 0.285682	valid_0's auc: 0.777811
# [480]	valid_0's binary_logloss: 0.28568	valid_0's auc: 0.777796
# [481]	valid_0's binary_logloss: 0.285668	valid_0's auc: 0.777782
# [482]	valid_0's binary_logloss: 0.285699	valid_0's auc: 0.777669
# [483]	valid_0's binary_logloss: 0.2857	valid_0's auc: 0.777695
# [484]	valid_0's binary_logloss: 0.285691	valid_0's auc: 0.777708
# [485]	valid_0's binary_logloss: 0.285651	valid_0's auc: 0.777772
# [486]	valid_0's binary_logloss: 0.285615	valid_0's auc: 0.777807
# [487]	valid_0's binary_logloss: 0.285587	valid_0's auc: 0.777862
# [488]	valid_0's binary_logloss: 0.285568	valid_0's auc: 0.777875
# [489]	valid_0's binary_logloss: 0.285558	valid_0's auc: 0.777848
# [490]	valid_0's binary_logloss: 0.285533	valid_0's auc: 0.777929
# [491]	valid_0's binary_logloss: 0.285505	valid_0's auc: 0.777991
# [492]	valid_0's binary_logloss: 0.28548	valid_0's auc: 0.778043
# [493]	valid_0's binary_logloss: 0.285466	valid_0's auc: 0.77809
# [494]	valid_0's binary_logloss: 0.285446	valid_0's auc: 0.778127
# [495]	valid_0's binary_logloss: 0.285442	valid_0's auc: 0.778125
# [496]	valid_0's binary_logloss: 0.285449	valid_0's auc: 0.778099
# [497]	valid_0's binary_logloss: 0.285443	valid_0's auc: 0.778106
# [498]	valid_0's binary_logloss: 0.285422	valid_0's auc: 0.778146
# [499]	valid_0's binary_logloss: 0.285401	valid_0's auc: 0.778185
# [500]	valid_0's binary_logloss: 0.285396	valid_0's auc: 0.778192
# [501]	valid_0's binary_logloss: 0.285421	valid_0's auc: 0.778139
# [502]	valid_0's binary_logloss: 0.285429	valid_0's auc: 0.778091
# [503]	valid_0's binary_logloss: 0.285424	valid_0's auc: 0.778113
# [504]	valid_0's binary_logloss: 0.285404	valid_0's auc: 0.778146
# [505]	valid_0's binary_logloss: 0.285387	valid_0's auc: 0.778179
# [506]	valid_0's binary_logloss: 0.285397	valid_0's auc: 0.778123
# [507]	valid_0's binary_logloss: 0.285379	valid_0's auc: 0.778128
# [508]	valid_0's binary_logloss: 0.285378	valid_0's auc: 0.778097
# [509]	valid_0's binary_logloss: 0.285378	valid_0's auc: 0.778074
# [510]	valid_0's binary_logloss: 0.285374	valid_0's auc: 0.778
# [511]	valid_0's binary_logloss: 0.285378	valid_0's auc: 0.777996
# [512]	valid_0's binary_logloss: 0.285374	valid_0's auc: 0.778012
# [513]	valid_0's binary_logloss: 0.285369	valid_0's auc: 0.778044
# [514]	valid_0's binary_logloss: 0.285388	valid_0's auc: 0.778007
# [515]	valid_0's binary_logloss: 0.285397	valid_0's auc: 0.777985
# [516]	valid_0's binary_logloss: 0.285408	valid_0's auc: 0.777951
# [517]	valid_0's binary_logloss: 0.285418	valid_0's auc: 0.777912
# [518]	valid_0's binary_logloss: 0.285402	valid_0's auc: 0.777921
# [519]	valid_0's binary_logloss: 0.285397	valid_0's auc: 0.777903
# [520]	valid_0's binary_logloss: 0.285394	valid_0's auc: 0.777893
# [521]	valid_0's binary_logloss: 0.285391	valid_0's auc: 0.777883
# [522]	valid_0's binary_logloss: 0.285387	valid_0's auc: 0.777909
# [523]	valid_0's binary_logloss: 0.28536	valid_0's auc: 0.777961
# [524]	valid_0's binary_logloss: 0.285358	valid_0's auc: 0.77796
# [525]	valid_0's binary_logloss: 0.285338	valid_0's auc: 0.777956
# [526]	valid_0's binary_logloss: 0.285317	valid_0's auc: 0.77798
# [527]	valid_0's binary_logloss: 0.285292	valid_0's auc: 0.778056
# [528]	valid_0's binary_logloss: 0.285312	valid_0's auc: 0.777989
# [529]	valid_0's binary_logloss: 0.285324	valid_0's auc: 0.777952
# [530]	valid_0's binary_logloss: 0.285334	valid_0's auc: 0.777864
# [531]	valid_0's binary_logloss: 0.285311	valid_0's auc: 0.777929
# [532]	valid_0's binary_logloss: 0.28527	valid_0's auc: 0.777997
# [533]	valid_0's binary_logloss: 0.285252	valid_0's auc: 0.778042
# [534]	valid_0's binary_logloss: 0.285219	valid_0's auc: 0.778088
# [535]	valid_0's binary_logloss: 0.285187	valid_0's auc: 0.778129
# [536]	valid_0's binary_logloss: 0.285155	valid_0's auc: 0.778242
# [537]	valid_0's binary_logloss: 0.285154	valid_0's auc: 0.778235
# [538]	valid_0's binary_logloss: 0.285134	valid_0's auc: 0.778299
# [539]	valid_0's binary_logloss: 0.285144	valid_0's auc: 0.778258
# [540]	valid_0's binary_logloss: 0.285145	valid_0's auc: 0.778246
# [541]	valid_0's binary_logloss: 0.285135	valid_0's auc: 0.778253
# [542]	valid_0's binary_logloss: 0.285092	valid_0's auc: 0.778372
# [543]	valid_0's binary_logloss: 0.285029	valid_0's auc: 0.778523
# [544]	valid_0's binary_logloss: 0.284987	valid_0's auc: 0.778593
# [545]	valid_0's binary_logloss: 0.284991	valid_0's auc: 0.778593
# [546]	valid_0's binary_logloss: 0.284931	valid_0's auc: 0.778787
# [547]	valid_0's binary_logloss: 0.284906	valid_0's auc: 0.778855
# [548]	valid_0's binary_logloss: 0.284895	valid_0's auc: 0.778869
# [549]	valid_0's binary_logloss: 0.284896	valid_0's auc: 0.778852
# [550]	valid_0's binary_logloss: 0.284901	valid_0's auc: 0.778807
# [551]	valid_0's binary_logloss: 0.28488	valid_0's auc: 0.778821
# [552]	valid_0's binary_logloss: 0.284848	valid_0's auc: 0.778888
# [553]	valid_0's binary_logloss: 0.284829	valid_0's auc: 0.77892
# [554]	valid_0's binary_logloss: 0.284798	valid_0's auc: 0.77896
# [555]	valid_0's binary_logloss: 0.284766	valid_0's auc: 0.77904
# [556]	valid_0's binary_logloss: 0.284749	valid_0's auc: 0.779098
# [557]	valid_0's binary_logloss: 0.284726	valid_0's auc: 0.779159
# [558]	valid_0's binary_logloss: 0.28473	valid_0's auc: 0.779177
# [559]	valid_0's binary_logloss: 0.284714	valid_0's auc: 0.779183
# [560]	valid_0's binary_logloss: 0.284668	valid_0's auc: 0.779351
# [561]	valid_0's binary_logloss: 0.28465	valid_0's auc: 0.779398
# [562]	valid_0's binary_logloss: 0.284625	valid_0's auc: 0.77944
# [563]	valid_0's binary_logloss: 0.284629	valid_0's auc: 0.779429
# [564]	valid_0's binary_logloss: 0.284581	valid_0's auc: 0.779608
# [565]	valid_0's binary_logloss: 0.284575	valid_0's auc: 0.779626
# [566]	valid_0's binary_logloss: 0.28456	valid_0's auc: 0.779699
# [567]	valid_0's binary_logloss: 0.28454	valid_0's auc: 0.779751
# [568]	valid_0's binary_logloss: 0.284493	valid_0's auc: 0.779893
# [569]	valid_0's binary_logloss: 0.284492	valid_0's auc: 0.779898
# [570]	valid_0's binary_logloss: 0.284503	valid_0's auc: 0.779878
# [571]	valid_0's binary_logloss: 0.284492	valid_0's auc: 0.779913
# [572]	valid_0's binary_logloss: 0.284491	valid_0's auc: 0.77992
# [573]	valid_0's binary_logloss: 0.284498	valid_0's auc: 0.779889
# [574]	valid_0's binary_logloss: 0.28447	valid_0's auc: 0.779975
# [575]	valid_0's binary_logloss: 0.284455	valid_0's auc: 0.78004
# [576]	valid_0's binary_logloss: 0.284445	valid_0's auc: 0.780089
# [577]	valid_0's binary_logloss: 0.284458	valid_0's auc: 0.779994
# [578]	valid_0's binary_logloss: 0.284468	valid_0's auc: 0.779964
# [579]	valid_0's binary_logloss: 0.28443	valid_0's auc: 0.780024
# [580]	valid_0's binary_logloss: 0.284427	valid_0's auc: 0.780058
# [581]	valid_0's binary_logloss: 0.284404	valid_0's auc: 0.780186
# [582]	valid_0's binary_logloss: 0.284419	valid_0's auc: 0.780156
# [583]	valid_0's binary_logloss: 0.284419	valid_0's auc: 0.780159
# [584]	valid_0's binary_logloss: 0.284432	valid_0's auc: 0.780153
# [585]	valid_0's binary_logloss: 0.284422	valid_0's auc: 0.78016
# [586]	valid_0's binary_logloss: 0.284392	valid_0's auc: 0.780242
# [587]	valid_0's binary_logloss: 0.284397	valid_0's auc: 0.780233
# [588]	valid_0's binary_logloss: 0.284381	valid_0's auc: 0.780275
# [589]	valid_0's binary_logloss: 0.284339	valid_0's auc: 0.780364
# [590]	valid_0's binary_logloss: 0.284313	valid_0's auc: 0.780384
# [591]	valid_0's binary_logloss: 0.284316	valid_0's auc: 0.780387
# [592]	valid_0's binary_logloss: 0.284306	valid_0's auc: 0.780401
# [593]	valid_0's binary_logloss: 0.284272	valid_0's auc: 0.780454
# [594]	valid_0's binary_logloss: 0.284248	valid_0's auc: 0.780491
# [595]	valid_0's binary_logloss: 0.284234	valid_0's auc: 0.78057
# [596]	valid_0's binary_logloss: 0.284216	valid_0's auc: 0.780618
# [597]	valid_0's binary_logloss: 0.284198	valid_0's auc: 0.780678
# [598]	valid_0's binary_logloss: 0.284185	valid_0's auc: 0.78073
# [599]	valid_0's binary_logloss: 0.284198	valid_0's auc: 0.78072
# [600]	valid_0's binary_logloss: 0.28418	valid_0's auc: 0.780718
# [601]	valid_0's binary_logloss: 0.284153	valid_0's auc: 0.780758
# [602]	valid_0's binary_logloss: 0.284148	valid_0's auc: 0.780803
# [603]	valid_0's binary_logloss: 0.28414	valid_0's auc: 0.780824
# [604]	valid_0's binary_logloss: 0.284121	valid_0's auc: 0.780857
# [605]	valid_0's binary_logloss: 0.284138	valid_0's auc: 0.780826
# [606]	valid_0's binary_logloss: 0.284137	valid_0's auc: 0.780875
# [607]	valid_0's binary_logloss: 0.284156	valid_0's auc: 0.780836
# [608]	valid_0's binary_logloss: 0.284145	valid_0's auc: 0.78088
# [609]	valid_0's binary_logloss: 0.28414	valid_0's auc: 0.78093
# [610]	valid_0's binary_logloss: 0.284134	valid_0's auc: 0.780964
# [611]	valid_0's binary_logloss: 0.284116	valid_0's auc: 0.781065
# [612]	valid_0's binary_logloss: 0.284083	valid_0's auc: 0.781168
# [613]	valid_0's binary_logloss: 0.284094	valid_0's auc: 0.78113
# [614]	valid_0's binary_logloss: 0.284083	valid_0's auc: 0.781123
# [615]	valid_0's binary_logloss: 0.284029	valid_0's auc: 0.781305
# [616]	valid_0's binary_logloss: 0.284008	valid_0's auc: 0.781347
# [617]	valid_0's binary_logloss: 0.284013	valid_0's auc: 0.781329
# [618]	valid_0's binary_logloss: 0.284021	valid_0's auc: 0.781329
# [619]	valid_0's binary_logloss: 0.283992	valid_0's auc: 0.781421
# [620]	valid_0's binary_logloss: 0.283986	valid_0's auc: 0.78145
# [621]	valid_0's binary_logloss: 0.283994	valid_0's auc: 0.781458
# [622]	valid_0's binary_logloss: 0.283984	valid_0's auc: 0.781506
# [623]	valid_0's binary_logloss: 0.283961	valid_0's auc: 0.781574
# [624]	valid_0's binary_logloss: 0.283948	valid_0's auc: 0.781627
# [625]	valid_0's binary_logloss: 0.283936	valid_0's auc: 0.781636
# [626]	valid_0's binary_logloss: 0.283942	valid_0's auc: 0.781641
# [627]	valid_0's binary_logloss: 0.283935	valid_0's auc: 0.781622
# [628]	valid_0's binary_logloss: 0.283936	valid_0's auc: 0.781663
# [629]	valid_0's binary_logloss: 0.283911	valid_0's auc: 0.781732
# [630]	valid_0's binary_logloss: 0.28391	valid_0's auc: 0.781757
# [631]	valid_0's binary_logloss: 0.283904	valid_0's auc: 0.781753
# [632]	valid_0's binary_logloss: 0.283909	valid_0's auc: 0.78173
# [633]	valid_0's binary_logloss: 0.28389	valid_0's auc: 0.781744
# [634]	valid_0's binary_logloss: 0.283901	valid_0's auc: 0.781753
# [635]	valid_0's binary_logloss: 0.283896	valid_0's auc: 0.781746
# [636]	valid_0's binary_logloss: 0.283875	valid_0's auc: 0.781793
# [637]	valid_0's binary_logloss: 0.283879	valid_0's auc: 0.781834
# [638]	valid_0's binary_logloss: 0.283861	valid_0's auc: 0.781866
# [639]	valid_0's binary_logloss: 0.283834	valid_0's auc: 0.781924
# [640]	valid_0's binary_logloss: 0.283852	valid_0's auc: 0.781851
# [641]	valid_0's binary_logloss: 0.283859	valid_0's auc: 0.781858
# [642]	valid_0's binary_logloss: 0.283842	valid_0's auc: 0.781878
# [643]	valid_0's binary_logloss: 0.283832	valid_0's auc: 0.781924
# [644]	valid_0's binary_logloss: 0.283829	valid_0's auc: 0.781955
# [645]	valid_0's binary_logloss: 0.283796	valid_0's auc: 0.782076
# [646]	valid_0's binary_logloss: 0.283809	valid_0's auc: 0.782068
# [647]	valid_0's binary_logloss: 0.283825	valid_0's auc: 0.78205
# [648]	valid_0's binary_logloss: 0.283841	valid_0's auc: 0.781992
# [649]	valid_0's binary_logloss: 0.283826	valid_0's auc: 0.782015
# [650]	valid_0's binary_logloss: 0.283854	valid_0's auc: 0.781972
# [651]	valid_0's binary_logloss: 0.283868	valid_0's auc: 0.781957
# [652]	valid_0's binary_logloss: 0.283855	valid_0's auc: 0.781952
# [653]	valid_0's binary_logloss: 0.283885	valid_0's auc: 0.781873
# [654]	valid_0's binary_logloss: 0.283879	valid_0's auc: 0.781902
# [655]	valid_0's binary_logloss: 0.283905	valid_0's auc: 0.781841
# [656]	valid_0's binary_logloss: 0.283908	valid_0's auc: 0.78184
# [657]	valid_0's binary_logloss: 0.283909	valid_0's auc: 0.781877
# [658]	valid_0's binary_logloss: 0.283931	valid_0's auc: 0.781813
# [659]	valid_0's binary_logloss: 0.283921	valid_0's auc: 0.781867
# [660]	valid_0's binary_logloss: 0.283925	valid_0's auc: 0.781848
# [661]	valid_0's binary_logloss: 0.283913	valid_0's auc: 0.781878
# [662]	valid_0's binary_logloss: 0.283902	valid_0's auc: 0.781863
# [663]	valid_0's binary_logloss: 0.283914	valid_0's auc: 0.781877
# [664]	valid_0's binary_logloss: 0.283905	valid_0's auc: 0.78193
# [665]	valid_0's binary_logloss: 0.283922	valid_0's auc: 0.781897
# [666]	valid_0's binary_logloss: 0.283928	valid_0's auc: 0.781919
# [667]	valid_0's binary_logloss: 0.283903	valid_0's auc: 0.781924
# [668]	valid_0's binary_logloss: 0.283876	valid_0's auc: 0.782
# [669]	valid_0's binary_logloss: 0.283881	valid_0's auc: 0.781957
# [670]	valid_0's binary_logloss: 0.283869	valid_0's auc: 0.781996
# [671]	valid_0's binary_logloss: 0.283884	valid_0's auc: 0.781968
# [672]	valid_0's binary_logloss: 0.283888	valid_0's auc: 0.781937
# [673]	valid_0's binary_logloss: 0.283875	valid_0's auc: 0.781994
# [674]	valid_0's binary_logloss: 0.283881	valid_0's auc: 0.781979
# [675]	valid_0's binary_logloss: 0.283868	valid_0's auc: 0.782009
# [676]	valid_0's binary_logloss: 0.283876	valid_0's auc: 0.782013
# [677]	valid_0's binary_logloss: 0.283853	valid_0's auc: 0.782084
# [678]	valid_0's binary_logloss: 0.283822	valid_0's auc: 0.782217
# [679]	valid_0's binary_logloss: 0.283847	valid_0's auc: 0.782196
# [680]	valid_0's binary_logloss: 0.283832	valid_0's auc: 0.782185
# [681]	valid_0's binary_logloss: 0.283848	valid_0's auc: 0.782132
# [682]	valid_0's binary_logloss: 0.283854	valid_0's auc: 0.782099
# [683]	valid_0's binary_logloss: 0.283853	valid_0's auc: 0.78213
# [684]	valid_0's binary_logloss: 0.283857	valid_0's auc: 0.782133
# [685]	valid_0's binary_logloss: 0.283857	valid_0's auc: 0.782103
# [686]	valid_0's binary_logloss: 0.283831	valid_0's auc: 0.782205
# [687]	valid_0's binary_logloss: 0.283844	valid_0's auc: 0.782183
# [688]	valid_0's binary_logloss: 0.283824	valid_0's auc: 0.78227
# [689]	valid_0's binary_logloss: 0.283837	valid_0's auc: 0.782251
# [690]	valid_0's binary_logloss: 0.283846	valid_0's auc: 0.782232
# [691]	valid_0's binary_logloss: 0.283844	valid_0's auc: 0.782269
# [692]	valid_0's binary_logloss: 0.283852	valid_0's auc: 0.78224
# [693]	valid_0's binary_logloss: 0.283835	valid_0's auc: 0.782264
# [694]	valid_0's binary_logloss: 0.283834	valid_0's auc: 0.782299
# [695]	valid_0's binary_logloss: 0.283849	valid_0's auc: 0.782299
# [696]	valid_0's binary_logloss: 0.283865	valid_0's auc: 0.78227
# [697]	valid_0's binary_logloss: 0.283885	valid_0's auc: 0.78223
# [698]	valid_0's binary_logloss: 0.283865	valid_0's auc: 0.782283
# [699]	valid_0's binary_logloss: 0.283867	valid_0's auc: 0.782283
# [700]	valid_0's binary_logloss: 0.283878	valid_0's auc: 0.782248
# [701]	valid_0's binary_logloss: 0.283874	valid_0's auc: 0.782235
# [702]	valid_0's binary_logloss: 0.283891	valid_0's auc: 0.782176
# [703]	valid_0's binary_logloss: 0.283909	valid_0's auc: 0.782133
# [704]	valid_0's binary_logloss: 0.283918	valid_0's auc: 0.782089
# [705]	valid_0's binary_logloss: 0.283904	valid_0's auc: 0.782133
# [706]	valid_0's binary_logloss: 0.283906	valid_0's auc: 0.782153
# [707]	valid_0's binary_logloss: 0.283884	valid_0's auc: 0.782192
# [708]	valid_0's binary_logloss: 0.283874	valid_0's auc: 0.7822
# [709]	valid_0's binary_logloss: 0.283878	valid_0's auc: 0.782261
# [710]	valid_0's binary_logloss: 0.283874	valid_0's auc: 0.782276
# [711]	valid_0's binary_logloss: 0.283897	valid_0's auc: 0.782232
# [712]	valid_0's binary_logloss: 0.2839	valid_0's auc: 0.782265
# [713]	valid_0's binary_logloss: 0.283898	valid_0's auc: 0.7823
# [714]	valid_0's binary_logloss: 0.283869	valid_0's auc: 0.78243
# [715]	valid_0's binary_logloss: 0.283852	valid_0's auc: 0.782458
# [716]	valid_0's binary_logloss: 0.283864	valid_0's auc: 0.782442
# [717]	valid_0's binary_logloss: 0.283864	valid_0's auc: 0.782445
# [718]	valid_0's binary_logloss: 0.283852	valid_0's auc: 0.782439
# [719]	valid_0's binary_logloss: 0.283828	valid_0's auc: 0.782515
# [720]	valid_0's binary_logloss: 0.283855	valid_0's auc: 0.782426
# [721]	valid_0's binary_logloss: 0.283849	valid_0's auc: 0.782418
# [722]	valid_0's binary_logloss: 0.283873	valid_0's auc: 0.782396
# [723]	valid_0's binary_logloss: 0.283869	valid_0's auc: 0.782419
# [724]	valid_0's binary_logloss: 0.283849	valid_0's auc: 0.782489
# [725]	valid_0's binary_logloss: 0.283796	valid_0's auc: 0.782601
# [726]	valid_0's binary_logloss: 0.283829	valid_0's auc: 0.782519
# [727]	valid_0's binary_logloss: 0.283843	valid_0's auc: 0.782461
# [728]	valid_0's binary_logloss: 0.283836	valid_0's auc: 0.782436
# [729]	valid_0's binary_logloss: 0.283853	valid_0's auc: 0.782384
# [730]	valid_0's binary_logloss: 0.283853	valid_0's auc: 0.782378
# [731]	valid_0's binary_logloss: 0.283838	valid_0's auc: 0.782417
# [732]	valid_0's binary_logloss: 0.283833	valid_0's auc: 0.782454
# [733]	valid_0's binary_logloss: 0.283842	valid_0's auc: 0.782429
# [734]	valid_0's binary_logloss: 0.283816	valid_0's auc: 0.782465
# [735]	valid_0's binary_logloss: 0.283831	valid_0's auc: 0.782439
# [736]	valid_0's binary_logloss: 0.283836	valid_0's auc: 0.782412
# [737]	valid_0's binary_logloss: 0.283833	valid_0's auc: 0.782405
# [738]	valid_0's binary_logloss: 0.283848	valid_0's auc: 0.782398
# [739]	valid_0's binary_logloss: 0.283834	valid_0's auc: 0.782444
# [740]	valid_0's binary_logloss: 0.283856	valid_0's auc: 0.782402
# [741]	valid_0's binary_logloss: 0.283873	valid_0's auc: 0.782422
# [742]	valid_0's binary_logloss: 0.283883	valid_0's auc: 0.782411
# [743]	valid_0's binary_logloss: 0.283869	valid_0's auc: 0.782438
# [744]	valid_0's binary_logloss: 0.28387	valid_0's auc: 0.782443
# [745]	valid_0's binary_logloss: 0.283847	valid_0's auc: 0.782486
# [746]	valid_0's binary_logloss: 0.28382	valid_0's auc: 0.782577
# [747]	valid_0's binary_logloss: 0.283808	valid_0's auc: 0.782602
# [748]	valid_0's binary_logloss: 0.283815	valid_0's auc: 0.782626
# [749]	valid_0's binary_logloss: 0.283822	valid_0's auc: 0.782598
# [750]	valid_0's binary_logloss: 0.283837	valid_0's auc: 0.782556
# [751]	valid_0's binary_logloss: 0.283858	valid_0's auc: 0.782538
# [752]	valid_0's binary_logloss: 0.283838	valid_0's auc: 0.782539
# [753]	valid_0's binary_logloss: 0.283854	valid_0's auc: 0.782511
# [754]	valid_0's binary_logloss: 0.283865	valid_0's auc: 0.782447
# [755]	valid_0's binary_logloss: 0.283857	valid_0's auc: 0.782442
# [756]	valid_0's binary_logloss: 0.283864	valid_0's auc: 0.782418
# [757]	valid_0's binary_logloss: 0.28387	valid_0's auc: 0.782429
# [758]	valid_0's binary_logloss: 0.283887	valid_0's auc: 0.782401
# [759]	valid_0's binary_logloss: 0.283897	valid_0's auc: 0.782361
# [760]	valid_0's binary_logloss: 0.283901	valid_0's auc: 0.782357
# [761]	valid_0's binary_logloss: 0.283911	valid_0's auc: 0.782345
# [762]	valid_0's binary_logloss: 0.28389	valid_0's auc: 0.782421
# [763]	valid_0's binary_logloss: 0.283875	valid_0's auc: 0.782514
# [764]	valid_0's binary_logloss: 0.283872	valid_0's auc: 0.782519
# [765]	valid_0's binary_logloss: 0.283893	valid_0's auc: 0.782479
# [766]	valid_0's binary_logloss: 0.283894	valid_0's auc: 0.782515
# [767]	valid_0's binary_logloss: 0.283895	valid_0's auc: 0.782531
# [768]	valid_0's binary_logloss: 0.283903	valid_0's auc: 0.782504
# [769]	valid_0's binary_logloss: 0.283883	valid_0's auc: 0.782561
# [770]	valid_0's binary_logloss: 0.283881	valid_0's auc: 0.782562
# [771]	valid_0's binary_logloss: 0.283878	valid_0's auc: 0.782576
# [772]	valid_0's binary_logloss: 0.283877	valid_0's auc: 0.782547
# [773]	valid_0's binary_logloss: 0.283855	valid_0's auc: 0.782612
# [774]	valid_0's binary_logloss: 0.283834	valid_0's auc: 0.782632
# [775]	valid_0's binary_logloss: 0.283835	valid_0's auc: 0.782629
# [776]	valid_0's binary_logloss: 0.283826	valid_0's auc: 0.7827
# [777]	valid_0's binary_logloss: 0.283828	valid_0's auc: 0.782752
# [778]	valid_0's binary_logloss: 0.283815	valid_0's auc: 0.782834
# [779]	valid_0's binary_logloss: 0.283817	valid_0's auc: 0.782873
# [780]	valid_0's binary_logloss: 0.283828	valid_0's auc: 0.782828
# [781]	valid_0's binary_logloss: 0.283829	valid_0's auc: 0.782813
# [782]	valid_0's binary_logloss: 0.283818	valid_0's auc: 0.782808
# [783]	valid_0's binary_logloss: 0.283815	valid_0's auc: 0.782851
# [784]	valid_0's binary_logloss: 0.283795	valid_0's auc: 0.78295
# [785]	valid_0's binary_logloss: 0.283772	valid_0's auc: 0.783018
# [786]	valid_0's binary_logloss: 0.283762	valid_0's auc: 0.783061
# [787]	valid_0's binary_logloss: 0.283763	valid_0's auc: 0.783044
# [788]	valid_0's binary_logloss: 0.283747	valid_0's auc: 0.783124
# [789]	valid_0's binary_logloss: 0.283751	valid_0's auc: 0.78309
# [790]	valid_0's binary_logloss: 0.283762	valid_0's auc: 0.783091
# [791]	valid_0's binary_logloss: 0.283773	valid_0's auc: 0.783058
# [792]	valid_0's binary_logloss: 0.283774	valid_0's auc: 0.783083
# [793]	valid_0's binary_logloss: 0.283771	valid_0's auc: 0.783105
# [794]	valid_0's binary_logloss: 0.283748	valid_0's auc: 0.783134
# [795]	valid_0's binary_logloss: 0.283784	valid_0's auc: 0.783065
# [796]	valid_0's binary_logloss: 0.283786	valid_0's auc: 0.783087
# [797]	valid_0's binary_logloss: 0.28381	valid_0's auc: 0.783036
# [798]	valid_0's binary_logloss: 0.283783	valid_0's auc: 0.783161
# [799]	valid_0's binary_logloss: 0.283789	valid_0's auc: 0.783179
# [800]	valid_0's binary_logloss: 0.283762	valid_0's auc: 0.783261
# [801]	valid_0's binary_logloss: 0.283773	valid_0's auc: 0.783206
# [802]	valid_0's binary_logloss: 0.283751	valid_0's auc: 0.783273
# [803]	valid_0's binary_logloss: 0.283758	valid_0's auc: 0.783281
# [804]	valid_0's binary_logloss: 0.283784	valid_0's auc: 0.783244
# [805]	valid_0's binary_logloss: 0.283777	valid_0's auc: 0.783246
# [806]	valid_0's binary_logloss: 0.283796	valid_0's auc: 0.783215
# [807]	valid_0's binary_logloss: 0.283814	valid_0's auc: 0.783208
# [808]	valid_0's binary_logloss: 0.283831	valid_0's auc: 0.783158
# [809]	valid_0's binary_logloss: 0.283846	valid_0's auc: 0.783163
# [810]	valid_0's binary_logloss: 0.283851	valid_0's auc: 0.783161
# [811]	valid_0's binary_logloss: 0.283858	valid_0's auc: 0.783172
# [812]	valid_0's binary_logloss: 0.283839	valid_0's auc: 0.783185
# [813]	valid_0's binary_logloss: 0.283833	valid_0's auc: 0.783214
# [814]	valid_0's binary_logloss: 0.283832	valid_0's auc: 0.783234
# [815]	valid_0's binary_logloss: 0.283841	valid_0's auc: 0.783239
# [816]	valid_0's binary_logloss: 0.283841	valid_0's auc: 0.783252
# [817]	valid_0's binary_logloss: 0.283833	valid_0's auc: 0.78327
# [818]	valid_0's binary_logloss: 0.283842	valid_0's auc: 0.783293
# [819]	valid_0's binary_logloss: 0.283831	valid_0's auc: 0.783374
# [820]	valid_0's binary_logloss: 0.283852	valid_0's auc: 0.783346
# [821]	valid_0's binary_logloss: 0.283838	valid_0's auc: 0.783393
# [822]	valid_0's binary_logloss: 0.283829	valid_0's auc: 0.783415
# [823]	valid_0's binary_logloss: 0.283869	valid_0's auc: 0.783357
# [824]	valid_0's binary_logloss: 0.283856	valid_0's auc: 0.783352
# [825]	valid_0's binary_logloss: 0.283829	valid_0's auc: 0.78344
# [826]	valid_0's binary_logloss: 0.283827	valid_0's auc: 0.78345
# [827]	valid_0's binary_logloss: 0.28384	valid_0's auc: 0.783439
# [828]	valid_0's binary_logloss: 0.283834	valid_0's auc: 0.783452
# [829]	valid_0's binary_logloss: 0.283828	valid_0's auc: 0.783456
# [830]	valid_0's binary_logloss: 0.283813	valid_0's auc: 0.78348
# [831]	valid_0's binary_logloss: 0.283812	valid_0's auc: 0.783558
# [832]	valid_0's binary_logloss: 0.283806	valid_0's auc: 0.783572
# [833]	valid_0's binary_logloss: 0.28382	valid_0's auc: 0.783529
# [834]	valid_0's binary_logloss: 0.283808	valid_0's auc: 0.783551
# [835]	valid_0's binary_logloss: 0.283799	valid_0's auc: 0.783568
# [836]	valid_0's binary_logloss: 0.283796	valid_0's auc: 0.783586
# [837]	valid_0's binary_logloss: 0.283803	valid_0's auc: 0.783565
# [838]	valid_0's binary_logloss: 0.283802	valid_0's auc: 0.783621
# [839]	valid_0's binary_logloss: 0.283794	valid_0's auc: 0.783662
# [840]	valid_0's binary_logloss: 0.283798	valid_0's auc: 0.783673
# [841]	valid_0's binary_logloss: 0.283821	valid_0's auc: 0.783616
# [842]	valid_0's binary_logloss: 0.283818	valid_0's auc: 0.783641
# [843]	valid_0's binary_logloss: 0.283826	valid_0's auc: 0.783619
# [844]	valid_0's binary_logloss: 0.28381	valid_0's auc: 0.78368
# [845]	valid_0's binary_logloss: 0.283807	valid_0's auc: 0.783721
# [846]	valid_0's binary_logloss: 0.283785	valid_0's auc: 0.783801
# [847]	valid_0's binary_logloss: 0.283786	valid_0's auc: 0.783818
# [848]	valid_0's binary_logloss: 0.283786	valid_0's auc: 0.783823
# [849]	valid_0's binary_logloss: 0.283786	valid_0's auc: 0.783822
# [850]	valid_0's binary_logloss: 0.283803	valid_0's auc: 0.783818
# [851]	valid_0's binary_logloss: 0.283826	valid_0's auc: 0.783779
# [852]	valid_0's binary_logloss: 0.283812	valid_0's auc: 0.783814
# [853]	valid_0's binary_logloss: 0.28382	valid_0's auc: 0.783814
# [854]	valid_0's binary_logloss: 0.283803	valid_0's auc: 0.783845
# [855]	valid_0's binary_logloss: 0.28379	valid_0's auc: 0.783898
# [856]	valid_0's binary_logloss: 0.283765	valid_0's auc: 0.783962
# [857]	valid_0's binary_logloss: 0.28375	valid_0's auc: 0.783979
# [858]	valid_0's binary_logloss: 0.283734	valid_0's auc: 0.784019
# [859]	valid_0's binary_logloss: 0.283743	valid_0's auc: 0.783991
# [860]	valid_0's binary_logloss: 0.283761	valid_0's auc: 0.783922
# [861]	valid_0's binary_logloss: 0.283758	valid_0's auc: 0.78394
# [862]	valid_0's binary_logloss: 0.283736	valid_0's auc: 0.783991
# [863]	valid_0's binary_logloss: 0.283745	valid_0's auc: 0.784012
# [864]	valid_0's binary_logloss: 0.283723	valid_0's auc: 0.784072
# [865]	valid_0's binary_logloss: 0.283755	valid_0's auc: 0.784035
# [866]	valid_0's binary_logloss: 0.283798	valid_0's auc: 0.783977
# [867]	valid_0's binary_logloss: 0.283799	valid_0's auc: 0.783937
# [868]	valid_0's binary_logloss: 0.283795	valid_0's auc: 0.783934
# [869]	valid_0's binary_logloss: 0.283789	valid_0's auc: 0.783948
# [870]	valid_0's binary_logloss: 0.283779	valid_0's auc: 0.784005
# [871]	valid_0's binary_logloss: 0.283765	valid_0's auc: 0.784044
# [872]	valid_0's binary_logloss: 0.283797	valid_0's auc: 0.783964
# [873]	valid_0's binary_logloss: 0.283795	valid_0's auc: 0.784007
# [874]	valid_0's binary_logloss: 0.283822	valid_0's auc: 0.783941
# [875]	valid_0's binary_logloss: 0.283845	valid_0's auc: 0.783923
# [876]	valid_0's binary_logloss: 0.283846	valid_0's auc: 0.783938
# [877]	valid_0's binary_logloss: 0.283843	valid_0's auc: 0.783938
# [878]	valid_0's binary_logloss: 0.28382	valid_0's auc: 0.783967
# [879]	valid_0's binary_logloss: 0.283811	valid_0's auc: 0.78399
# [880]	valid_0's binary_logloss: 0.283806	valid_0's auc: 0.783994
# [881]	valid_0's binary_logloss: 0.283824	valid_0's auc: 0.783929
# [882]	valid_0's binary_logloss: 0.283806	valid_0's auc: 0.783991
# [883]	valid_0's binary_logloss: 0.283811	valid_0's auc: 0.783982
# [884]	valid_0's binary_logloss: 0.283827	valid_0's auc: 0.783946
# [885]	valid_0's binary_logloss: 0.283812	valid_0's auc: 0.783974
# [886]	valid_0's binary_logloss: 0.283795	valid_0's auc: 0.78405
# [887]	valid_0's binary_logloss: 0.283819	valid_0's auc: 0.784012
# [888]	valid_0's binary_logloss: 0.28383	valid_0's auc: 0.784025
# [889]	valid_0's binary_logloss: 0.283831	valid_0's auc: 0.784031
# [890]	valid_0's binary_logloss: 0.28385	valid_0's auc: 0.783991
# [891]	valid_0's binary_logloss: 0.28384	valid_0's auc: 0.783998
# [892]	valid_0's binary_logloss: 0.283831	valid_0's auc: 0.784028
# [893]	valid_0's binary_logloss: 0.283824	valid_0's auc: 0.784042
# [894]	valid_0's binary_logloss: 0.283831	valid_0's auc: 0.783995
# [895]	valid_0's binary_logloss: 0.283814	valid_0's auc: 0.784015
# [896]	valid_0's binary_logloss: 0.283823	valid_0's auc: 0.784011
# [897]	valid_0's binary_logloss: 0.283813	valid_0's auc: 0.784132
# [898]	valid_0's binary_logloss: 0.283841	valid_0's auc: 0.784091
# [899]	valid_0's binary_logloss: 0.283833	valid_0's auc: 0.784097
# [900]	valid_0's binary_logloss: 0.283836	valid_0's auc: 0.784062
# [901]	valid_0's binary_logloss: 0.283864	valid_0's auc: 0.784039
# [902]	valid_0's binary_logloss: 0.283876	valid_0's auc: 0.784022
# [903]	valid_0's binary_logloss: 0.283851	valid_0's auc: 0.78414
# [904]	valid_0's binary_logloss: 0.283838	valid_0's auc: 0.784161
# [905]	valid_0's binary_logloss: 0.283842	valid_0's auc: 0.784116
# [906]	valid_0's binary_logloss: 0.283825	valid_0's auc: 0.784138
# [907]	valid_0's binary_logloss: 0.283819	valid_0's auc: 0.78416
# [908]	valid_0's binary_logloss: 0.283822	valid_0's auc: 0.78417
# [909]	valid_0's binary_logloss: 0.283816	valid_0's auc: 0.784192
# [910]	valid_0's binary_logloss: 0.283813	valid_0's auc: 0.784193
# [911]	valid_0's binary_logloss: 0.283804	valid_0's auc: 0.784203
# [912]	valid_0's binary_logloss: 0.283826	valid_0's auc: 0.784154
# [913]	valid_0's binary_logloss: 0.283832	valid_0's auc: 0.784164
# [914]	valid_0's binary_logloss: 0.283853	valid_0's auc: 0.784145
# [915]	valid_0's binary_logloss: 0.283863	valid_0's auc: 0.784119
# [916]	valid_0's binary_logloss: 0.283853	valid_0's auc: 0.784136
# [917]	valid_0's binary_logloss: 0.283841	valid_0's auc: 0.784128
# [918]	valid_0's binary_logloss: 0.283855	valid_0's auc: 0.784125
# [919]	valid_0's binary_logloss: 0.283861	valid_0's auc: 0.784096
# [920]	valid_0's binary_logloss: 0.28388	valid_0's auc: 0.784036
# [921]	valid_0's binary_logloss: 0.283878	valid_0's auc: 0.784036
# [922]	valid_0's binary_logloss: 0.283895	valid_0's auc: 0.784004
# [923]	valid_0's binary_logloss: 0.283905	valid_0's auc: 0.78399
# [924]	valid_0's binary_logloss: 0.283886	valid_0's auc: 0.784028
# [925]	valid_0's binary_logloss: 0.283859	valid_0's auc: 0.784108
# [926]	valid_0's binary_logloss: 0.283845	valid_0's auc: 0.784148
# [927]	valid_0's binary_logloss: 0.283828	valid_0's auc: 0.784206
# [928]	valid_0's binary_logloss: 0.283851	valid_0's auc: 0.784157
# [929]	valid_0's binary_logloss: 0.283846	valid_0's auc: 0.784197
# [930]	valid_0's binary_logloss: 0.28387	valid_0's auc: 0.784106
# [931]	valid_0's binary_logloss: 0.28385	valid_0's auc: 0.784151
# [932]	valid_0's binary_logloss: 0.283863	valid_0's auc: 0.784115
# [933]	valid_0's binary_logloss: 0.283851	valid_0's auc: 0.784143
# [934]	valid_0's binary_logloss: 0.283831	valid_0's auc: 0.784196
# [935]	valid_0's binary_logloss: 0.28381	valid_0's auc: 0.784238
# [936]	valid_0's binary_logloss: 0.283825	valid_0's auc: 0.784168
# [937]	valid_0's binary_logloss: 0.283834	valid_0's auc: 0.784211
# [938]	valid_0's binary_logloss: 0.283815	valid_0's auc: 0.784246
# [939]	valid_0's binary_logloss: 0.283822	valid_0's auc: 0.78423
# [940]	valid_0's binary_logloss: 0.283809	valid_0's auc: 0.7843
# [941]	valid_0's binary_logloss: 0.283791	valid_0's auc: 0.784358
# [942]	valid_0's binary_logloss: 0.28379	valid_0's auc: 0.784345
# [943]	valid_0's binary_logloss: 0.283791	valid_0's auc: 0.784315
# [944]	valid_0's binary_logloss: 0.2838	valid_0's auc: 0.784313
# [945]	valid_0's binary_logloss: 0.283807	valid_0's auc: 0.784293
# [946]	valid_0's binary_logloss: 0.283823	valid_0's auc: 0.784273
# [947]	valid_0's binary_logloss: 0.283831	valid_0's auc: 0.784235
# [948]	valid_0's binary_logloss: 0.283832	valid_0's auc: 0.784237
# [949]	valid_0's binary_logloss: 0.283811	valid_0's auc: 0.784298
# [950]	valid_0's binary_logloss: 0.283786	valid_0's auc: 0.78437
# [951]	valid_0's binary_logloss: 0.283805	valid_0's auc: 0.784337
# [952]	valid_0's binary_logloss: 0.283836	valid_0's auc: 0.784278
# [953]	valid_0's binary_logloss: 0.283824	valid_0's auc: 0.784311
# [954]	valid_0's binary_logloss: 0.283854	valid_0's auc: 0.784244
# [955]	valid_0's binary_logloss: 0.28385	valid_0's auc: 0.784249
# [956]	valid_0's binary_logloss: 0.28386	valid_0's auc: 0.784231
# [957]	valid_0's binary_logloss: 0.283863	valid_0's auc: 0.784222
# [958]	valid_0's binary_logloss: 0.28387	valid_0's auc: 0.784211
# [959]	valid_0's binary_logloss: 0.283854	valid_0's auc: 0.784301
# [960]	valid_0's binary_logloss: 0.28386	valid_0's auc: 0.784297
# [961]	valid_0's binary_logloss: 0.283868	valid_0's auc: 0.784272
# [962]	valid_0's binary_logloss: 0.283862	valid_0's auc: 0.784294
# [963]	valid_0's binary_logloss: 0.283876	valid_0's auc: 0.78427
# [964]	valid_0's binary_logloss: 0.283879	valid_0's auc: 0.78427
# Early stopping, best iteration is:
# [864]	valid_0's binary_logloss: 0.283723	valid_0's auc: 0.784072
# Save model...
# Wall time: 1.57 s

# %%
# predict
y_pred_lgb = gbm.predict(X_test, num_iteration=gbm.best_iteration)

print('Test accuracy is: ', np.mean(y_test == (y_pred_lgb > .5)))
# Out:
# Test accuracy is:  0.8970657832465688

# %% [markdown]
# ### Feature Importance

# %%
df_featImp = pd.DataFrame({'Feature': gbm.feature_name(), 'Importance':gbm.feature_importance()})

# %%
plt.figure(figsize=(11,8))
sns.barplot(y='Feature', x='Importance', data=df_featImp.sort_values(by='Importance', ascending=False), orient='h')

# %% [markdown]
# ### ROC and AUC

# %%
from sklearn.metrics import roc_curve, auc

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
fpr["LightGBM"], tpr["LightGBM"], _ = roc_curve(y_test, y_pred_lgb)
roc_auc["LightGBM"] = auc(fpr["LightGBM"], tpr["LightGBM"])

plt.figure(figsize=(10, 7))
plt.plot(fpr["LightGBM"], tpr["LightGBM"],
         label='LightGBM AUC = {0:0.2f}'
               ''.format(roc_auc["LightGBM"]),
         color='deeppink')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools

# %%
def plot_confusion_matrix(y_test, y_pred, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    cm = confusion_matrix(y_test, y_pred)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plt.figure(figsize=(9, 9))
plot_confusion_matrix(y_test, y_pred_lgb > .3, ['notWon', 'isWon'], title="Confusion Matrix for LightGBM")

# %% [markdown]
# ## B. Logistic Regression on Non-missing Features

# %% [markdown]
# Logistic Regression cannot work with missing values. We fit a logistic regression with non-missing features.

# %%
from sklearn.linear_model import LogisticRegression

# %%
# convert back Label Encoding
inv_LabelMap = dict()
for i in LabelMap.keys():
    inv_LabelMap[i] = {v: k for k, v in LabelMap[i].items()}

# %%
X_train.replace(inv_LabelMap, inplace=True)
X_test.replace(inv_LabelMap, inplace=True)

# %%
Xtrain_logi = X_train.drop(['ATS__c','Industry'], axis=1).join(pd.get_dummies(X_train['ATS__c'], prefix='ATS__c')).join(pd.get_dummies(X_train['Industry'], prefix='Industry'))
Xtest_logi = X_test.drop(['ATS__c','Industry'], axis=1).join(pd.get_dummies(X_test['ATS__c'], prefix='ATS__c')).join(pd.get_dummies(X_test['Industry'], prefix='Industry'))

# %%
missing_col = datatrain.apply(lambda x: sum(x.isna()), axis=0).sort_values()[datatrain.apply(lambda x: sum(x.isna()), axis=0).sort_values() > 0].index.tolist()

# %%
logi = LogisticRegression(max_iter=10000)
logi.fit(Xtrain_logi.drop(missing_col, axis=1), y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=10000, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred_logi1 = logi.predict_proba(Xtest_logi.drop(missing_col, axis=1))
print('Test Accuracy is: ', np.mean(y_test == (y_pred_logi1[:,0] > .8)))
# Out:
# Test Accuracy is:  0.5511121628017037

# %% [markdown]
# ### The result is terrible! Therefore, we decide to impute the missing values and use all the features. We use median value as the strategy.

# %%
from sklearn.preprocessing import Imputer
my_imputer = Imputer(strategy='median')

# %%
new_Xtrain = Xtrain_logi.copy()
new_Xtest = Xtest_logi.copy()

for col in missing_col:
    new_Xtrain[col + '_was_missing'] = new_Xtrain[col].isnull()
    new_Xtest[col + '_was_missing'] = new_Xtest[col].isnull()

new_Xtrain = my_imputer.fit_transform(new_Xtrain)
new_Xtest = my_imputer.fit_transform(new_Xtest)

# %%
logi = LogisticRegression(max_iter=10000)
logi.fit(new_Xtrain, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=10000, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ### Logistic Regression with imputing missing values still give us a terrible performance. The accuracy is basically predicting all cases as True cases.

# %%
y_pred_logi2 = logi.predict_proba(new_Xtest)
print('Test Accuracy is: ', np.mean(y_test == (y_pred_logi2[:,0] > .5)))
# Out:
# Test Accuracy is:  0.10648367250354945

# %% [markdown]
# ### ROC and AUC

# %%
df_pred = pd.DataFrame({'LightGBM':y_pred_lgb, "Logistic_no_miss":y_pred_logi1[:,0], "Logistic_impute":y_pred_logi2[:,0]})
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in ['LightGBM', "Logistic_no_miss", "Logistic_impute"]:
    fpr[i], tpr[i], _ = roc_curve(y_test, df_pred[i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %% [markdown]
# ROC and AUC also shows the same terrible performances of Logistic Regressions.

# %%
plt.figure(figsize=(10, 7))
plt.plot(fpr["LightGBM"], tpr["LightGBM"],
         label='LightGBM AUC = {0:0.2f}'
               ''.format(roc_auc["LightGBM"]),
         color='deeppink')

plt.plot(fpr["Logistic_no_miss"], tpr["Logistic_no_miss"],
         label='Logistic_no_miss AUC = {0:0.4f}'
               ''.format(roc_auc["Logistic_no_miss"]),
         color='navy')

plt.plot(fpr["Logistic_impute"], tpr["Logistic_impute"],
         label='Logistic_no_miss AUC = {0:0.4f}'
               ''.format(roc_auc["Logistic_impute"]),
         color='green')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Fit LightGBM Model to the Run Data

# %%
datarun.drop('employerId', axis=1).dtypes
# Out:
# ATS__c                      int64
# Industry                    int64
# numJobs                   float64
# awards                    float64
# contentCount              float64
# followers                 float64
# freshContent              float64
# photos                    float64
# starRating                float64
# clicks                    float64
# monthOfSignupPageViews    float64
# timeOnSite                  int64
# intDifficulty             float64
# intDuration               float64
# has_interviews              int64
# basePayAmount             float64
# subsidiary                  int64
# employeesTotalNum         float64
# RespondedContacts         float64
# dtype: object

# %%
run_pred_lgb = gbm.predict(datarun.drop('employerId', axis=1), num_iteration=gbm.best_iteration)

# %%
datarun['isWon'] = run_pred_lgb

# %% [markdown]
# ### Export Prediction

# %%
datarun.to_csv("output/prediction.csv")
